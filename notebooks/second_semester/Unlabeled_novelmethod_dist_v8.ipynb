# %% [markdown]
# Experiments to run:
#
# Note: Fix random seed numpy, pytorch (data splitting), log data to csv files, run each 5 times
#
# 1. Dataset:
#   1.   Increase training size
#   2.   Decrease unlabeled data size
#
# 2. Methods:
#   1.   Distillation with lambdas: 0., 0.3, 0.5, 0.7, 0.9
#   2.   Distillation with unlabeled with soft labels from teacher ../../
#   3.   Distillation method with similar lambdas
#   4.   Distillation method with unlabeled ../../
#
# 3. Metrics:
#   1.   Good churn
#   2.   Bad churn
#   3.   Churn ratio
#   4.   Accuracy

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import torchvision
import numpy as np
import os
from tqdm import tqdm
device = 'cuda' if torch.cuda.is_available() else 'cpu'
from sklearn.mixture import GaussianMixture
from typing import Union

N_EPOCHS = 50

# %%
# Set the seed for PyTorch
torch.manual_seed(42)

# Set the seed for NumPy
np.random.seed(42)

class ChurnMetric:
    """
    Super class for metrics.
    """

    def __init__(self, tensor_type="numpy") -> None:
        tensor_types = {"numpy": np.ndarray, "torch": torch.Tensor}
        if tensor_type not in tensor_types:
            raise NotImplementedError("Unknown object type")
        self.tensor_type = tensor_types[tensor_type]

    def call_sanitize_inputs(self, **preds):
        """
        preds can be true labels as well
        Shape of tensors need to be the same.
        Tensor dim len must not be >2
        """
        for p in preds:
            if not isinstance(preds[p], self.tensor_type):
                raise TypeError(f"{p} is not an instance of {str(self.tensor_type)}")
            if len(preds[p].shape) > 2:
                raise ValueError(f"Too many dims in {p}")
        shapes = set([preds[p].shape for p in preds])
        if len(shapes) > 1:  # TODO extend to force only first dim to be the same
            raise ValueError(f"shape mismatch. shapes of preds must be same")

    def reshape_argmax(self, **preds):
        for p in preds:
            if len(preds[p].shape) == 2 and preds[p].shape[1] > 1:
                preds[p] = preds[p].argmax(1)
        return (preds[p] for p in preds)


class Churn(ChurnMetric):
    """
    Simple Churn. Calculates number of classification disagreements, along axis:0.
    Will take argmax if multiple columns.
    """

    def __init__(self, tensor_type="numpy", output_mode="proportion") -> None:
        super(Churn, self).__init__(tensor_type=tensor_type)
        if output_mode not in {"proportion", "count"}:
            raise ValueError("Unknown output_mode")
        self.output_mode = output_mode

    def __call__(
        self,
        predA: Union[np.ndarray, torch.Tensor],
        predB: Union[np.ndarray, torch.Tensor],
    ) -> None:
        self.call_sanitize_inputs(predA=predA, predB=predB)
        predA, predB = self.reshape_argmax(predA=predA, predB=predB)

        churn = sum(predA != predB)

        if self.output_mode == "proportion":
            return churn / predA.shape[0]
        if self.output_mode == "count":
            return churn


class WinLossRatio(ChurnMetric):
    """
    Lateral Churns are not loss
    """

    def __init__(self, tensor_type="numpy") -> None:
        super().__init__(tensor_type)

    def __call__(self, true_labels, pred_teacher, pred_student):
        self.call_sanitize_inputs(
            true_labels=true_labels,
            pred_teacher=pred_teacher,
            pred_student=pred_student,
        )
        true_labels, pred_teacher, pred_student = self.reshape_argmax(
            true_labels, pred_teacher, pred_student
        )

        pred_teacher = pred_teacher == true_labels
        pred_student = pred_student == true_labels
        wins = sum(pred_student > pred_teacher)
        losses = sum(pred_student < pred_teacher)

        return wins / (losses + 1e-7)


class ChurnRatio(ChurnMetric):
    def __init__(self, tensor_type="numpy") -> None:
        super().__init__(tensor_type)

    def __call__(self, pred_teacher, pred_student, pred_control):
        self.call_sanitize_inputs(
            pred_teacher=pred_teacher,
            pred_student=pred_student,
            pred_control=pred_control,
        )
        pred_teacher, pred_student, pred_control = self.reshape_argmax(
            pred_teacher, pred_student, pred_control
        )

        churnratio = sum(pred_student != pred_teacher) / sum(
            pred_control != pred_teacher
        )
        return churnratio


class GoodBadChurn(ChurnMetric):
    """
    lateral churn is bad
    """

    def __init__(
        self, tensor_type="numpy", mode=None, output_mode="proportion"
    ) -> None:
        super().__init__(tensor_type)
        if mode is None or mode not in {"good", "bad"}:
            raise ValueError("Please specify mode as good or bad")
        self.mode = mode
        if output_mode not in {"proportion", "count"}:
            raise ValueError("Unknown output_mode")
        self.output_mode = output_mode

    def __call__(self, true_labels, pred_teacher, pred_student):
        self.call_sanitize_inputs(
            true_labels=true_labels,
            pred_teacher=pred_teacher,
            pred_student=pred_student,
        )
        true_labels, pred_teacher, pred_student = self.reshape_argmax(
            true_labels=true_labels, pred_teacher=pred_teacher, pred_student=pred_student,
        )

        if self.mode == "good":
            churn = sum((pred_student == true_labels) > (pred_teacher == true_labels))
            if self.output_mode == "proportion":
                denominator = sum((pred_student == true_labels))
                return churn / denominator
            elif self.output_mode == "count":
                return churn

        elif self.mode == "bad":
            churn = sum(
                (pred_student == true_labels) < (pred_teacher == true_labels)
            ) + sum(
                (pred_student != true_labels)
                & (pred_teacher != true_labels)
                & (pred_teacher != pred_student)
            )
            if self.output_mode == "proportion":
                raise NotImplementedError("IDK")
            elif self.output_mode == "count":
                return churn

# %% [markdown]
# Init datasets

# %%
# Set the seed for PyTorch
torch.manual_seed(42)

# Set the seed for NumPy
np.random.seed(42)

#torch transform
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,)),
])

new_classes = [3,5,7]
regular_classes = [0,1,2,4,6,8,9]

#Create Train Sets
total_datasets = [
    torchvision.datasets.FashionMNIST(root='./data', train=True, download=True, transform=transform),
    torchvision.datasets.FashionMNIST(root='./data', train=False, download=True, transform=transform),
]

total_dict = {
    "x": torch.concat([d.data for d in total_datasets]),
    "y": torch.concat([d.targets for d in total_datasets]),
}
total_dict["id"] = np.array(range(total_dict["y"].shape[0]))
total_dict["field"] = np.array(['NoneNoneNone']*total_dict['y'].shape[0])

for c in regular_classes:
    c_ids = total_dict["id"][np.where(total_dict["y"]==c)[0]]
    field = np.array(["oldtrain"]*4400 + ["test"]*800 + ["val"]*800 + ["unlab"]*1000 + ["new"]*0)
    np.random.shuffle(field)    
    total_dict['field'][c_ids] = field
for c in new_classes:
    c_ids = total_dict["id"][np.where(total_dict["y"]==c)[0]]
    field = np.array(["oldtrain"]*3900 + ["test"]*800 + ["val"]*800 + ["unlab"]*500 + ["new"]*1000)
    np.random.shuffle(field)
    total_dict['field'][c_ids] = field

sets = {
    ss: torch.utils.data.TensorDataset(
        total_dict['x'][total_dict['field']==ss],
        total_dict['y'][total_dict['field']==ss],
    ) for ss in ["oldtrain", "test", "val", "new"]
}
sets["unlab"] = torch.utils.data.TensorDataset(
    total_dict['x'][total_dict['field']=="unlab"],
    total_dict['y'][total_dict['field']=="unlab"],
)
sets['mixed'] = torch.utils.data.TensorDataset(
    torch.concat([
    total_dict['x'][total_dict['field']=="oldtrain"],
    total_dict['x'][total_dict['field']=="new"],
]),
torch.concat([
    total_dict['y'][total_dict['field']=="oldtrain"],
    total_dict['y'][total_dict['field']=="new"],
])
)

# %% [markdown]
# Model architecture

# %%
# class CNN(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.features = nn.Sequential( #28*28
#             nn.Conv2d(in_channels=1, out_channels=6, kernel_size=5, stride=1, padding=2, bias=True),
#             nn.ReLU(),
#             nn.BatchNorm2d(6),
#             nn.MaxPool2d(2),
#             nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5, stride=1, padding=0, bias=True),
#             nn.ReLU(),
#             nn.BatchNorm2d(16),
#             nn.MaxPool2d(2),
#         )
#         self.fully_connected = nn.Sequential(
#             nn.Linear(in_features=16*5*5, out_features=120),
#             nn.ReLU(),
#             nn.Dropout(0.25),
#             nn.BatchNorm1d(120),
#             nn.Linear(in_features=120, out_features=84),
#             nn.ReLU(),
#             nn.Dropout(0.25),
#             nn.BatchNorm1d(84),
#             nn.Linear(in_features=84, out_features=10),
#         )

#     def forward(self, x):
#         x = self.features(x)
#         x = x.view(x.size(0), -1)
#         x = self.fully_connected(x)
#         return x

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 3, 1)
        self.conv2 = nn.Conv2d(32, 64, 3, 1)
        self.dropout1 = nn.Dropout2d(0.25)
        self.dropout2 = nn.Dropout2d(0.5)
        self.fc1 = nn.Linear(9216, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.conv2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)
        x = self.dropout1(x)
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.dropout2(x)
        x = self.fc2(x)
        output = F.log_softmax(x, dim=1)
        return output

# %% [markdown]
# ### Simple CNN

# %%
# class CNN(nn.Module):
#     def __init__(self):
#         super(CNN, self).__init__()
#         self.conv1 = nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1)
#         self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
#         self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
#         self.fc1 = nn.Linear(32 * 7 * 7, 128)
#         self.fc2 = nn.Linear(128, 10)

#     def forward(self, x):
#         x = self.pool(torch.relu(self.conv1(x)))
#         x = self.pool(torch.relu(self.conv2(x)))
#         x = x.view(-1, 32 * 7 * 7)
#         x = torch.relu(self.fc1(x))
#         x = self.fc2(x)
#         return x

# %% [markdown]
# Init models

# %%
batch_size = 256
loaders = {
    ss: torch.utils.data.DataLoader(sets[ss], batch_size=batch_size, shuffle=False)
    for ss in ["oldtrain", "mixed", "test", "unlab", "val", "new"]
}

# %% [markdown]
# Train Teacher

# %%
from copy import deepcopy

def train(name, loader, init_val_loss=1e7, n_epochs=N_EPOCHS):
    # Set the seed for PyTorch
    torch.manual_seed(42)

    # Set the seed for NumPy
    np.random.seed(42)
    model = CNN()
    model.to(device)
    optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
    n_epochs = n_epochs
    best_val_loss = init_val_loss
    best_state_dict = deepcopy(model.state_dict())
    loss_fn = torch.nn.CrossEntropyLoss()
    for epoch in range(n_epochs):
        # running_loss = 0.0
        for i, (x,y) in tqdm(enumerate(loader), disable=True,):
            x = x.unsqueeze(1).float()
            x = x.to(device)
            y = y.to(device)
            optimizer.zero_grad()
            pred = model(x)
            loss = loss_fn(pred, y)
            loss.backward()
            optimizer.step() 
        print('Epoch [{}/{}], Loss: {:.4f}'
                   .format(epoch+1, n_epochs, loss.item()))

            
        val_loss = 0.0
        correct = 0
        total = 0
        with torch.no_grad():
            for i,data in enumerate(loader):
                x, y = data
                x = x.to(device)
                y = y.to(device)
                x = x.unsqueeze(1).float()
                outputs = model(x)
                _, predicted = torch.max(outputs.data, 1)
                total += y.size(0)
                correct += (predicted == y).sum().item()
                val_loss += loss_fn(outputs, y).item()
            if val_loss < best_val_loss:
                model.to('cpu')
                model.eval()
                torch.save(model.state_dict(), name+".pth")
                model.train()
                model.to(device)
                best_val_loss = val_loss
                # print(f"best at epoch {epoch}")
        # print('[%d] validation loss: %.5f' % (epoch+1, val_loss))
                print('Accuracy of the model on the test images: {:.2f} %'.format(100 * correct / total))
                print('Validation error of the model on the test images: {:.4f}'.format(val_loss / len(loader)))
    return model

# %%
def train_dist(name, loader, init_val_loss=1e7, n_epochs=N_EPOCHS):
    # Set the seed for PyTorch
    torch.manual_seed(42)

    # Set the seed for NumPy
    np.random.seed(42)
    model = CNN()
    model.to(device)
    optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
    n_epochs = n_epochs
    best_val_loss = init_val_loss
    loss_fn = torch.nn.CrossEntropyLoss()
    for epoch in range(n_epochs):
        # running_loss = 0.0
        for i, (x,y) in tqdm(enumerate(loader), disable=True,):
            x = x.unsqueeze(1).float()
            x = x.to(device)
            y = y.to(device)
            optimizer.zero_grad()
            pred = model(x)
            loss = loss_fn(pred, y)
            loss.backward()
            optimizer.step() 
        print('Epoch [{}/{}], Loss: {:.4f}'
                   .format(epoch+1, n_epochs, loss.item()))

            
        val_loss = 0.0
        correct = 0
        total = 0
        with torch.no_grad():
            for i,data in enumerate(loader):
                x, y = data
                x = x.to(device)
                y = y.to(device)
                x = x.unsqueeze(1).float()
                outputs = model(x)
                _, predicted = torch.max(outputs.data, 1)
                _, dist_y = torch.max(y.data, 1)
                total += y.size(0)
                correct += (predicted == dist_y).sum().item()
                val_loss += loss_fn(outputs, y).item()
            if val_loss < best_val_loss:
                model.to('cpu')
                model.eval()
                torch.save(model.state_dict(), name+".pth")
                model.train()
                model.to(device)
                best_val_loss = val_loss
                # print(f"best at epoch {epoch}")
        # print('[%d] validation loss: %.5f' % (epoch+1, val_loss))
                print('Accuracy of the model on the test images: {:.2f} %'.format(100 * correct / total))
                print('Validation error of the model on the test images: {:.4f}'.format(val_loss / len(loader)))
    return model

# %% [markdown]
# Generate Teacher Predicted Labels

# %%
train(
    name="teacher_model", 
    loader=loaders["oldtrain"],
)
teacher_model = CNN()
teacher_model.load_state_dict(torch.load("teacher_model.pth"))
teacher_model.eval()
None
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/nn/functional.py:1331: UserWarning: dropout2d: Received a 2-D input to dropout2d, which is deprecated and will result in an error in a future release. To retain the behavior and silence this warning, please use dropout instead. Note that dropout2d exists to provide channel-wise dropout on inputs with 2 spatial dimensions, a channel dimension, and an optional batch dimension (i.e. 3D or 4D inputs).
#   warnings.warn(warn_msg)
# Epoch [1/50], Loss: 0.2973
# Accuracy of the model on the test images: 81.29 %
# Validation error of the model on the test images: 0.5215
# Epoch [2/50], Loss: 0.0527
# Accuracy of the model on the test images: 84.20 %
# Validation error of the model on the test images: 0.4443
# Epoch [3/50], Loss: 0.2244
# Accuracy of the model on the test images: 85.74 %
# Validation error of the model on the test images: 0.3994
# Epoch [4/50], Loss: 0.0148
# Accuracy of the model on the test images: 86.67 %
# Validation error of the model on the test images: 0.3655
# Epoch [5/50], Loss: 0.0396
# Accuracy of the model on the test images: 87.24 %
# Validation error of the model on the test images: 0.3506
# Epoch [6/50], Loss: 0.0044
# Accuracy of the model on the test images: 87.95 %
# Validation error of the model on the test images: 0.3300
# Epoch [7/50], Loss: 0.0007
# Accuracy of the model on the test images: 88.58 %
# Validation error of the model on the test images: 0.3130
# Epoch [8/50], Loss: 0.0218
# Accuracy of the model on the test images: 89.07 %
# Validation error of the model on the test images: 0.2994
# Epoch [9/50], Loss: 0.0194
# Accuracy of the model on the test images: 89.24 %
# Validation error of the model on the test images: 0.2910
# Epoch [10/50], Loss: 0.0008
# Accuracy of the model on the test images: 89.72 %
# Validation error of the model on the test images: 0.2768
# Epoch [11/50], Loss: 0.0023
# Accuracy of the model on the test images: 90.06 %
# Validation error of the model on the test images: 0.2735
# Epoch [12/50], Loss: 0.0001
# Accuracy of the model on the test images: 90.15 %
# Validation error of the model on the test images: 0.2658
# Epoch [13/50], Loss: 0.0471
# Accuracy of the model on the test images: 90.56 %
# Validation error of the model on the test images: 0.2546
# Epoch [14/50], Loss: 0.0083
# Accuracy of the model on the test images: 90.55 %
# Validation error of the model on the test images: 0.2502
# Epoch [15/50], Loss: 0.0002
# Accuracy of the model on the test images: 91.03 %
# Validation error of the model on the test images: 0.2436
# Epoch [16/50], Loss: 0.0040
# Accuracy of the model on the test images: 91.43 %
# Validation error of the model on the test images: 0.2290
# Epoch [17/50], Loss: 0.0027
# Accuracy of the model on the test images: 91.58 %
# Validation error of the model on the test images: 0.2248
# Epoch [18/50], Loss: 0.0037
# Epoch [19/50], Loss: 0.0001
# Accuracy of the model on the test images: 91.88 %
# Validation error of the model on the test images: 0.2149
# Epoch [20/50], Loss: 0.0022
# Accuracy of the model on the test images: 92.15 %
# Validation error of the model on the test images: 0.2099
# Epoch [21/50], Loss: 0.0020
# Accuracy of the model on the test images: 92.23 %
# Validation error of the model on the test images: 0.2077
# Epoch [22/50], Loss: 0.0006
# Accuracy of the model on the test images: 92.67 %
# Validation error of the model on the test images: 0.1976
# Epoch [23/50], Loss: 0.1508
# Accuracy of the model on the test images: 92.60 %
# Validation error of the model on the test images: 0.1970
# Epoch [24/50], Loss: 0.0012
# Accuracy of the model on the test images: 92.67 %
# Validation error of the model on the test images: 0.1936
# Epoch [25/50], Loss: 0.0000
# Accuracy of the model on the test images: 92.90 %
# Validation error of the model on the test images: 0.1865
# Epoch [26/50], Loss: 0.0617
# Accuracy of the model on the test images: 93.30 %
# Validation error of the model on the test images: 0.1783
# Epoch [27/50], Loss: 0.0004
# Accuracy of the model on the test images: 93.42 %
# Validation error of the model on the test images: 0.1744
# Epoch [28/50], Loss: 0.0000
# Epoch [29/50], Loss: 0.0042
# Accuracy of the model on the test images: 93.71 %
# Validation error of the model on the test images: 0.1683
# Epoch [30/50], Loss: 0.0002
# Accuracy of the model on the test images: 93.76 %
# Validation error of the model on the test images: 0.1667
# Epoch [31/50], Loss: 0.0000
# Accuracy of the model on the test images: 93.69 %
# Validation error of the model on the test images: 0.1650
# Epoch [32/50], Loss: 0.0001
# Accuracy of the model on the test images: 93.84 %
# Validation error of the model on the test images: 0.1615
# Epoch [33/50], Loss: 0.0000
# Accuracy of the model on the test images: 94.07 %
# Validation error of the model on the test images: 0.1553
# Epoch [34/50], Loss: 0.0000
# Accuracy of the model on the test images: 94.16 %
# Validation error of the model on the test images: 0.1522
# Epoch [35/50], Loss: 0.0008
# Accuracy of the model on the test images: 94.28 %
# Validation error of the model on the test images: 0.1502
# Epoch [36/50], Loss: 0.2379
# Accuracy of the model on the test images: 94.43 %
# Validation error of the model on the test images: 0.1467
# Epoch [37/50], Loss: 0.0015
# Accuracy of the model on the test images: 94.54 %
# Validation error of the model on the test images: 0.1464
# Epoch [38/50], Loss: 0.0001
# Epoch [39/50], Loss: 0.0000
# Accuracy of the model on the test images: 94.40 %
# Validation error of the model on the test images: 0.1464
# Epoch [40/50], Loss: 0.0002
# Accuracy of the model on the test images: 94.66 %
# Validation error of the model on the test images: 0.1407
# Epoch [41/50], Loss: 0.0000
# Accuracy of the model on the test images: 94.76 %
# Validation error of the model on the test images: 0.1346
# Epoch [42/50], Loss: 0.0000
# Accuracy of the model on the test images: 94.90 %
# Validation error of the model on the test images: 0.1337
# Epoch [43/50], Loss: 0.0011
# Accuracy of the model on the test images: 94.96 %
# Validation error of the model on the test images: 0.1326
# Epoch [44/50], Loss: 0.0000
# Accuracy of the model on the test images: 95.16 %
# Validation error of the model on the test images: 0.1315
# Epoch [45/50], Loss: 0.0000
# Accuracy of the model on the test images: 95.04 %
# Validation error of the model on the test images: 0.1305
# Epoch [46/50], Loss: 0.0000
# Accuracy of the model on the test images: 94.93 %
# Validation error of the model on the test images: 0.1291
# Epoch [47/50], Loss: 0.0005
# Accuracy of the model on the test images: 95.22 %
# Validation error of the model on the test images: 0.1232
# Epoch [48/50], Loss: 0.0001
# Accuracy of the model on the test images: 95.45 %
# Validation error of the model on the test images: 0.1198
# Epoch [49/50], Loss: 0.0000
# Epoch [50/50], Loss: 0.0022
# Accuracy of the model on the test images: 95.53 %
# Validation error of the model on the test images: 0.1169

# %%
#Get train labels on train mixed data
with torch.no_grad():
    teacher_labels_mixed = []
    for (x,y) in tqdm(loaders['mixed']):
        x = x.unsqueeze(1).float()
        pred = teacher_model(x)
        teacher_labels_mixed.append(pred)
    teacher_labels_mixed = torch.concatenate(teacher_labels_mixed).argmax(dim=1)
sets['teacher_mixed'] = torch.utils.data.TensorDataset(
    torch.concat([
    total_dict['x'][total_dict['field']=="oldtrain"],
    total_dict['x'][total_dict['field']=="new"],
]),
    teacher_labels_mixed,
)
# Out:
# 100%|██████████| 178/178 [00:35<00:00,  5.01it/s]

# %%
import torch.nn.functional as F

# Get train labels on unlabelled data
with torch.no_grad():
    unlab_teacherpred = []
    for (x,i) in tqdm(loaders['unlab']):
        x = x.unsqueeze(1).float()
        pred = teacher_model(x)
        probs = F.softmax(pred, dim=1)
        unlab_teacherpred.append(probs)
    unlab_teacherpred = torch.cat(unlab_teacherpred, dim=0)  # Concatenate the list of tensors


  # 0.1, 0.8, 0.1 : conf=0.8, pred=1
  # 0.1, 0.3, 0.6 : conf=0.6, pred=2
# Out:
# 100%|██████████| 34/34 [00:07<00:00,  4.86it/s]

# %%
# unlab_teacherpred_conf, unlab_teacherpred = torch.concatenate(unlab_teacherpred).max(dim=1)

# %% [markdown]
# ### Misclassifications

# %%
true_mix = torch.concat([
    total_dict['y'][total_dict['field']=="oldtrain"],
    total_dict['y'][total_dict['field']=="new"],
])

teacher_labels_mixed

# Compare the tensors element-wise
mask = true_mix != teacher_labels_mixed

# Get the indices of the non-matching elements
indices = torch.where(mask)

# %%
# get the unique elements and their counts
unique, counts = torch.unique(true_mix[indices[0]], return_counts=True)

# print the results
for u, c in zip(unique, np.round(100*counts/len(true_mix),2)):
    print('Element {}: {:.2f}%'.format(u, c))
# Out:
# Element 0: 0.27%
# Element 1: 0.00%
# Element 2: 0.23%
# Element 3: 0.22%
# Element 4: 0.22%
# Element 5: 0.04%
# Element 6: 0.30%
# Element 7: 0.07%
# Element 8: 0.00%
# Element 9: 0.07%

# %% [markdown]
# ## Adding Unlabeled Data

# %%
X_new = total_dict['x'][total_dict['field']=="new"].flatten(start_dim=1).numpy()
X_mixed = torch.concat([
    total_dict['x'][total_dict['field']=="oldtrain"],
    total_dict['x'][total_dict['field']=="new"],
]).flatten(start_dim=1).numpy()
X_unlab = total_dict['x'][total_dict['field']=="unlab"].flatten(start_dim=1).numpy()
y_mixed = torch.concat([
    total_dict['y'][total_dict['field']=="oldtrain"],
    total_dict['y'][total_dict['field']=="new"],
])

# %%
#relabel based on threshold
confidence_threshold = 1.0

# gmm_labels = teacher_labels_mixed
lamda = 0.0
gmm_labels = F.one_hot(teacher_labels_mixed, num_classes=10) * (lamda) + F.one_hot(sets['mixed'].tensors[1], num_classes=10) * (1-lamda)
#gmm_labels[loglik_mixed > threshold] = y_mixed[loglik_mixed > threshold]
#unlabeled data
# unlab_condition = torch.isin(unlab_teacherpred, torch.tensor(regular_classes))
sets["teacher_unlab"] = torch.utils.data.TensorDataset(
    total_dict['x'][np.isin(total_dict['field'], ["unlab"])],
    unlab_teacherpred
)

sets["gmm"] = torch.utils.data.TensorDataset(
    torch.concat([
        sets['mixed'].tensors[0],
        sets['unlab'].tensors[0],
    ]),
    torch.concat([
        gmm_labels,
       unlab_teacherpred
    ]),
)
loaders['gmm'] = torch.utils.data.DataLoader(sets["gmm"], batch_size=batch_size, shuffle=False)

# %%
#y_new = total_dict['y'][total_dict['field']=="new"]

# %%
#y_unlab = total_dict['y'][total_dict['field']=="unlab"].flatten(start_dim=0).numpy()

# %% [markdown]
# Train unlabel based CNN model

# %%
train_dist(
    name="student_unlab_model", 
    loader=loaders['gmm'],
)
student_gmm_model = CNN()
student_gmm_model.load_state_dict(torch.load("student_unlab_model.pth"))
student_gmm_model.eval()
None
# Out:
# Epoch [1/50], Loss: 0.5667
# Accuracy of the model on the test images: 81.30 %
# Validation error of the model on the test images: 0.5320
# Epoch [2/50], Loss: 0.5181
# Accuracy of the model on the test images: 82.55 %
# Validation error of the model on the test images: 0.4875
# Epoch [3/50], Loss: 0.4027
# Accuracy of the model on the test images: 84.76 %
# Validation error of the model on the test images: 0.4280
# Epoch [4/50], Loss: 0.3960
# Accuracy of the model on the test images: 85.58 %
# Validation error of the model on the test images: 0.4045
# Epoch [5/50], Loss: 0.3838
# Accuracy of the model on the test images: 86.43 %
# Validation error of the model on the test images: 0.3797
# Epoch [6/50], Loss: 0.3291
# Accuracy of the model on the test images: 87.56 %
# Validation error of the model on the test images: 0.3482
# Epoch [7/50], Loss: 0.3164
# Accuracy of the model on the test images: 87.89 %
# Validation error of the model on the test images: 0.3356
# Epoch [8/50], Loss: 0.2947
# Accuracy of the model on the test images: 88.52 %
# Validation error of the model on the test images: 0.3245
# Epoch [9/50], Loss: 0.2820
# Accuracy of the model on the test images: 89.05 %
# Validation error of the model on the test images: 0.3037
# Epoch [10/50], Loss: 0.2893
# Accuracy of the model on the test images: 89.53 %
# Validation error of the model on the test images: 0.2914
# Epoch [11/50], Loss: 0.2780
# Accuracy of the model on the test images: 89.99 %
# Validation error of the model on the test images: 0.2807
# Epoch [12/50], Loss: 0.2681
# Accuracy of the model on the test images: 90.33 %
# Validation error of the model on the test images: 0.2699
# Epoch [13/50], Loss: 0.2549
# Accuracy of the model on the test images: 90.76 %
# Validation error of the model on the test images: 0.2603
# Epoch [14/50], Loss: 0.2756
# Accuracy of the model on the test images: 90.87 %
# Validation error of the model on the test images: 0.2523
# Epoch [15/50], Loss: 0.2805
# Accuracy of the model on the test images: 91.14 %
# Validation error of the model on the test images: 0.2506
# Epoch [16/50], Loss: 0.2338
# Accuracy of the model on the test images: 91.42 %
# Validation error of the model on the test images: 0.2462
# Epoch [17/50], Loss: 0.2634
# Accuracy of the model on the test images: 91.69 %
# Validation error of the model on the test images: 0.2357
# Epoch [18/50], Loss: 0.2308
# Accuracy of the model on the test images: 91.52 %
# Validation error of the model on the test images: 0.2350
# Epoch [19/50], Loss: 0.2779
# Accuracy of the model on the test images: 91.99 %
# Validation error of the model on the test images: 0.2252
# Epoch [20/50], Loss: 0.2477
# Accuracy of the model on the test images: 92.04 %
# Validation error of the model on the test images: 0.2208
# Epoch [21/50], Loss: 0.2384
# Accuracy of the model on the test images: 92.46 %
# Validation error of the model on the test images: 0.2128
# Epoch [22/50], Loss: 0.2435
# Accuracy of the model on the test images: 92.57 %
# Validation error of the model on the test images: 0.2099
# Epoch [23/50], Loss: 0.2400
# Accuracy of the model on the test images: 92.87 %
# Validation error of the model on the test images: 0.2049
# Epoch [24/50], Loss: 0.2398
# Accuracy of the model on the test images: 92.83 %
# Validation error of the model on the test images: 0.2009
# Epoch [25/50], Loss: 0.2252
# Accuracy of the model on the test images: 92.87 %
# Validation error of the model on the test images: 0.2007
# Epoch [26/50], Loss: 0.2383
# Accuracy of the model on the test images: 92.95 %
# Validation error of the model on the test images: 0.1961
# Epoch [27/50], Loss: 0.2415
# Accuracy of the model on the test images: 93.13 %
# Validation error of the model on the test images: 0.1945
# Epoch [28/50], Loss: 0.2386
# Accuracy of the model on the test images: 93.58 %
# Validation error of the model on the test images: 0.1849
# Epoch [29/50], Loss: 0.2646
# Accuracy of the model on the test images: 93.53 %
# Validation error of the model on the test images: 0.1834
# Epoch [30/50], Loss: 0.2221
# Accuracy of the model on the test images: 93.79 %
# Validation error of the model on the test images: 0.1787
# Epoch [31/50], Loss: 0.2243
# Epoch [32/50], Loss: 0.2224
# Accuracy of the model on the test images: 93.97 %
# Validation error of the model on the test images: 0.1725
# Epoch [33/50], Loss: 0.2458
# Accuracy of the model on the test images: 94.04 %
# Validation error of the model on the test images: 0.1721
# Epoch [34/50], Loss: 0.2199
# Accuracy of the model on the test images: 94.06 %
# Validation error of the model on the test images: 0.1709
# Epoch [35/50], Loss: 0.2496
# Accuracy of the model on the test images: 94.23 %
# Validation error of the model on the test images: 0.1659
# Epoch [36/50], Loss: 0.2286
# Epoch [37/50], Loss: 0.2283
# Accuracy of the model on the test images: 94.33 %
# Validation error of the model on the test images: 0.1643
# Epoch [38/50], Loss: 0.2001
# Epoch [39/50], Loss: 0.2005
# Accuracy of the model on the test images: 94.60 %
# Validation error of the model on the test images: 0.1592
# Epoch [40/50], Loss: 0.2416
# Accuracy of the model on the test images: 94.60 %
# Validation error of the model on the test images: 0.1573
# Epoch [41/50], Loss: 0.2175
# Epoch [42/50], Loss: 0.2346
# Accuracy of the model on the test images: 94.76 %
# Validation error of the model on the test images: 0.1556
# Epoch [43/50], Loss: 0.2193
# Accuracy of the model on the test images: 94.88 %
# Validation error of the model on the test images: 0.1529
# Epoch [44/50], Loss: 0.2270
# Accuracy of the model on the test images: 94.84 %
# Validation error of the model on the test images: 0.1520
# Epoch [45/50], Loss: 0.2217
# Accuracy of the model on the test images: 94.98 %
# Validation error of the model on the test images: 0.1495
# Epoch [46/50], Loss: 0.2174
# Accuracy of the model on the test images: 95.10 %
# Validation error of the model on the test images: 0.1470
# Epoch [47/50], Loss: 0.2257
# Epoch [48/50], Loss: 0.2380
# Accuracy of the model on the test images: 95.16 %
# Validation error of the model on the test images: 0.1439
# Epoch [49/50], Loss: 0.2310
# Accuracy of the model on the test images: 95.26 %
# Validation error of the model on the test images: 0.1422
# Epoch [50/50], Loss: 0.2346
# Accuracy of the model on the test images: 95.33 %
# Validation error of the model on the test images: 0.1396

# %% [markdown]
# ## Distilation Method

# %%
lamda = 0.0
distill_labels = F.one_hot(teacher_labels_mixed, num_classes=10) * (lamda) + F.one_hot(sets['mixed'].tensors[1], num_classes=10) * (1-lamda)

sets["distill"] = torch.utils.data.TensorDataset(
    sets['mixed'].tensors[0],
    distill_labels,
)

loaders['distill'] = torch.utils.data.DataLoader(sets['distill'], batch_size=batch_size, shuffle=False)

# %%
loader=loaders['distill']

# %%
train_dist(
    name="student_distil_model", 
    loader=loaders['distill'],
)
student_distil_model = CNN()
student_distil_model.load_state_dict(torch.load("student_distil_model.pth"))
student_distil_model.eval()
None
# Out:
# Epoch [1/50], Loss: 0.0879
# Accuracy of the model on the test images: 48.62 %
# Validation error of the model on the test images: 3.2223
# Epoch [2/50], Loss: 0.1444
# Accuracy of the model on the test images: 60.06 %
# Validation error of the model on the test images: 1.7468
# Epoch [3/50], Loss: 0.1160
# Accuracy of the model on the test images: 67.58 %
# Validation error of the model on the test images: 1.2382
# Epoch [4/50], Loss: 0.0785
# Accuracy of the model on the test images: 70.22 %
# Validation error of the model on the test images: 1.0616
# Epoch [5/50], Loss: 0.0809
# Accuracy of the model on the test images: 72.26 %
# Validation error of the model on the test images: 0.9803
# Epoch [6/50], Loss: 0.0707
# Accuracy of the model on the test images: 76.14 %
# Validation error of the model on the test images: 0.7786
# Epoch [7/50], Loss: 0.0556
# Accuracy of the model on the test images: 79.10 %
# Validation error of the model on the test images: 0.6460
# Epoch [8/50], Loss: 0.0554
# Accuracy of the model on the test images: 82.94 %
# Validation error of the model on the test images: 0.5015
# Epoch [9/50], Loss: 0.0462
# Epoch [10/50], Loss: 0.0557
# Accuracy of the model on the test images: 84.58 %
# Validation error of the model on the test images: 0.4526
# Epoch [11/50], Loss: 0.0675
# Accuracy of the model on the test images: 84.60 %
# Validation error of the model on the test images: 0.4501
# Epoch [12/50], Loss: 0.0488
# Accuracy of the model on the test images: 85.17 %
# Validation error of the model on the test images: 0.4220
# Epoch [13/50], Loss: 0.0405
# Accuracy of the model on the test images: 86.09 %
# Validation error of the model on the test images: 0.4009
# Epoch [14/50], Loss: 0.0447
# Accuracy of the model on the test images: 86.16 %
# Validation error of the model on the test images: 0.3902
# Epoch [15/50], Loss: 0.0397
# Accuracy of the model on the test images: 87.40 %
# Validation error of the model on the test images: 0.3552
# Epoch [16/50], Loss: 0.0451
# Epoch [17/50], Loss: 0.0493
# Accuracy of the model on the test images: 88.30 %
# Validation error of the model on the test images: 0.3301
# Epoch [18/50], Loss: 0.0334
# Epoch [19/50], Loss: 0.0413
# Accuracy of the model on the test images: 89.27 %
# Validation error of the model on the test images: 0.3005
# Epoch [20/50], Loss: 0.0515
# Epoch [21/50], Loss: 0.0347
# Epoch [22/50], Loss: 0.0267
# Accuracy of the model on the test images: 89.40 %
# Validation error of the model on the test images: 0.2972
# Epoch [23/50], Loss: 0.0356
# Epoch [24/50], Loss: 0.0133
# Epoch [25/50], Loss: 0.0433
# Accuracy of the model on the test images: 89.78 %
# Validation error of the model on the test images: 0.2855
# Epoch [26/50], Loss: 0.0325
# Epoch [27/50], Loss: 0.0196
# Accuracy of the model on the test images: 90.36 %
# Validation error of the model on the test images: 0.2646
# Epoch [28/50], Loss: 0.0186
# Epoch [29/50], Loss: 0.0381
# Accuracy of the model on the test images: 91.37 %
# Validation error of the model on the test images: 0.2383
# Epoch [30/50], Loss: 0.0325
# Accuracy of the model on the test images: 91.28 %
# Validation error of the model on the test images: 0.2368
# Epoch [31/50], Loss: 0.0141
# Epoch [32/50], Loss: 0.0266
# Accuracy of the model on the test images: 91.86 %
# Validation error of the model on the test images: 0.2209
# Epoch [33/50], Loss: 0.0351
# Epoch [34/50], Loss: 0.0236
# Epoch [35/50], Loss: 0.0253
# Accuracy of the model on the test images: 92.11 %
# Validation error of the model on the test images: 0.2166
# Epoch [36/50], Loss: 0.0305
# Accuracy of the model on the test images: 92.67 %
# Validation error of the model on the test images: 0.2001
# Epoch [37/50], Loss: 0.0699
# Accuracy of the model on the test images: 92.64 %
# Validation error of the model on the test images: 0.2000
# Epoch [38/50], Loss: 0.0359
# Epoch [39/50], Loss: 0.0259
# Epoch [40/50], Loss: 0.0151
# Epoch [41/50], Loss: 0.0111
# Accuracy of the model on the test images: 92.70 %
# Validation error of the model on the test images: 0.1939
# Epoch [42/50], Loss: 0.0259
# Accuracy of the model on the test images: 93.50 %
# Validation error of the model on the test images: 0.1724
# Epoch [43/50], Loss: 0.0342
# Epoch [44/50], Loss: 0.0217
# Epoch [45/50], Loss: 0.0297
# Accuracy of the model on the test images: 93.54 %
# Validation error of the model on the test images: 0.1706
# Epoch [46/50], Loss: 0.0351
# Epoch [47/50], Loss: 0.0136
# Accuracy of the model on the test images: 93.71 %
# Validation error of the model on the test images: 0.1681
# Epoch [48/50], Loss: 0.0248
# Accuracy of the model on the test images: 93.92 %
# Validation error of the model on the test images: 0.1615
# Epoch [49/50], Loss: 0.0256
# Epoch [50/50], Loss: 0.0465
# Accuracy of the model on the test images: 94.35 %
# Validation error of the model on the test images: 0.1493

# %% [markdown]
# ## Baseline Method

# %%
train(
    name="baseline_model", 
    loader=loaders['mixed'],
)
baseline_model = CNN()
baseline_model.load_state_dict(torch.load("baseline_model.pth"))
baseline_model.eval()
None
# Out:
# Epoch [1/50], Loss: 0.0753
# Accuracy of the model on the test images: 50.64 %
# Validation error of the model on the test images: 2.9234
# Epoch [2/50], Loss: 0.1342
# Accuracy of the model on the test images: 58.07 %
# Validation error of the model on the test images: 1.8893
# Epoch [3/50], Loss: 0.1321
# Accuracy of the model on the test images: 68.21 %
# Validation error of the model on the test images: 1.1968
# Epoch [4/50], Loss: 0.0909
# Accuracy of the model on the test images: 72.85 %
# Validation error of the model on the test images: 0.9138
# Epoch [5/50], Loss: 0.0797
# Accuracy of the model on the test images: 76.18 %
# Validation error of the model on the test images: 0.8101
# Epoch [6/50], Loss: 0.0751
# Accuracy of the model on the test images: 76.40 %
# Validation error of the model on the test images: 0.7547
# Epoch [7/50], Loss: 0.0467
# Accuracy of the model on the test images: 80.99 %
# Validation error of the model on the test images: 0.5817
# Epoch [8/50], Loss: 0.0607
# Accuracy of the model on the test images: 83.79 %
# Validation error of the model on the test images: 0.4802
# Epoch [9/50], Loss: 0.0493
# Epoch [10/50], Loss: 0.0566
# Accuracy of the model on the test images: 84.51 %
# Validation error of the model on the test images: 0.4531
# Epoch [11/50], Loss: 0.0573
# Accuracy of the model on the test images: 85.29 %
# Validation error of the model on the test images: 0.4267
# Epoch [12/50], Loss: 0.0476
# Epoch [13/50], Loss: 0.0420
# Accuracy of the model on the test images: 87.17 %
# Validation error of the model on the test images: 0.3689
# Epoch [14/50], Loss: 0.0474
# Epoch [15/50], Loss: 0.0376
# Accuracy of the model on the test images: 87.49 %
# Validation error of the model on the test images: 0.3508
# Epoch [16/50], Loss: 0.0419
# Epoch [17/50], Loss: 0.0365
# Epoch [18/50], Loss: 0.0329
# Epoch [19/50], Loss: 0.0412
# Accuracy of the model on the test images: 88.14 %
# Validation error of the model on the test images: 0.3351
# Epoch [20/50], Loss: 0.0531
# Accuracy of the model on the test images: 88.87 %
# Validation error of the model on the test images: 0.3141
# Epoch [21/50], Loss: 0.0369
# Epoch [22/50], Loss: 0.0435
# Accuracy of the model on the test images: 90.06 %
# Validation error of the model on the test images: 0.2715
# Epoch [23/50], Loss: 0.0312
# Epoch [24/50], Loss: 0.0239
# Epoch [25/50], Loss: 0.0567
# Epoch [26/50], Loss: 0.0396
# Accuracy of the model on the test images: 90.42 %
# Validation error of the model on the test images: 0.2668
# Epoch [27/50], Loss: 0.0168
# Epoch [28/50], Loss: 0.0407
# Accuracy of the model on the test images: 91.16 %
# Validation error of the model on the test images: 0.2456
# Epoch [29/50], Loss: 0.0383
# Accuracy of the model on the test images: 91.25 %
# Validation error of the model on the test images: 0.2399
# Epoch [30/50], Loss: 0.0494
# Accuracy of the model on the test images: 91.66 %
# Validation error of the model on the test images: 0.2225
# Epoch [31/50], Loss: 0.0119
# Epoch [32/50], Loss: 0.0488
# Epoch [33/50], Loss: 0.0311
# Epoch [34/50], Loss: 0.0450
# Epoch [35/50], Loss: 0.0386
# Accuracy of the model on the test images: 92.40 %
# Validation error of the model on the test images: 0.2049
# Epoch [36/50], Loss: 0.0364
# Accuracy of the model on the test images: 92.54 %
# Validation error of the model on the test images: 0.2044
# Epoch [37/50], Loss: 0.0599
# Accuracy of the model on the test images: 92.79 %
# Validation error of the model on the test images: 0.1928
# Epoch [38/50], Loss: 0.0190
# Epoch [39/50], Loss: 0.0375
# Epoch [40/50], Loss: 0.0193
# Accuracy of the model on the test images: 92.86 %
# Validation error of the model on the test images: 0.1908
# Epoch [41/50], Loss: 0.0184
# Epoch [42/50], Loss: 0.0147
# Accuracy of the model on the test images: 93.22 %
# Validation error of the model on the test images: 0.1781
# Epoch [43/50], Loss: 0.0324
# Epoch [44/50], Loss: 0.0245
# Epoch [45/50], Loss: 0.0354
# Epoch [46/50], Loss: 0.0257
# Epoch [47/50], Loss: 0.0128
# Accuracy of the model on the test images: 93.73 %
# Validation error of the model on the test images: 0.1705
# Epoch [48/50], Loss: 0.0268
# Accuracy of the model on the test images: 93.89 %
# Validation error of the model on the test images: 0.1657
# Epoch [49/50], Loss: 0.0351
# Accuracy of the model on the test images: 93.91 %
# Validation error of the model on the test images: 0.1628
# Epoch [50/50], Loss: 0.0304
# Accuracy of the model on the test images: 94.40 %
# Validation error of the model on the test images: 0.1494

# %%
def accuracy(pred, true):
    return 100 * (pred==true).sum() / pred.shape[0]

def get_metrics(targets, loader):
    with torch.no_grad():
        good_churn = GoodBadChurn(mode="good", tensor_type="torch", output_mode = "count")
        bad_churn = GoodBadChurn(mode="bad", tensor_type="torch", output_mode = "count")
        pred_teacher = []
        pred_baseline = []
        pred_distill = []
        pred_gmm = []
        for (x,y) in tqdm(loader):
            x = x.unsqueeze(1).float()
            pred = teacher_model(x)
            pred_teacher.append(pred)
            pred = baseline_model(x)
            pred_baseline.append(pred)
            pred = student_distil_model(x)
            pred_distill.append(pred)
            pred = student_gmm_model(x)
            pred_gmm.append(pred)
        pred_teacher = torch.concatenate(pred_teacher).argmax(dim=1)
        pred_baseline = torch.concatenate(pred_baseline).argmax(dim=1)
        pred_distill = torch.concatenate(pred_distill).argmax(dim=1)
        pred_gmm = torch.concatenate(pred_gmm).argmax(dim=1)
        
        gchurns = {
            "baseline": good_churn(targets, pred_teacher, pred_baseline).item(),
            "add_unlab": good_churn(targets, pred_teacher, pred_gmm).item(),
            "anchor": good_churn(targets, pred_teacher, pred_distill).item(),
        }
        bchurns = {
            "baseline": bad_churn(targets, pred_teacher, pred_baseline).item(),
            "add_unlab": bad_churn(targets, pred_teacher, pred_gmm).item(),
            "anchor": bad_churn(targets, pred_teacher, pred_distill).item(),
        }
        accuracies = {
            "baseline": accuracy(pred_baseline, targets).item(),
            "add_unlab": accuracy(pred_gmm, targets).item(),
            "anchor": accuracy(pred_distill, targets).item(),
            "teacher": accuracy(pred_teacher, targets).item(),
        }
        return gchurns, bchurns, accuracies

# %%
metrics_dict = {   "gchurns_val":  {'baseline': 0, 'add_unlab': 0, 'anchor': 0},
                  "bchurns_val":  {'baseline': 0, 'add_unlab': 0, 'anchor': 0}, 
                  "accuracies_val": {'baseline': 0, 'add_unlab': 0, 'anchor': 0}}

metrics_dict_multiple = {
    x: metrics_dict.copy()
    for x in [0.0, 0.3, 0.5, 0.7, 0.9]
}

# %%
# gchurns_mixed, bchurns_mixed, accuracies_mixed = get_metrics(sets['mixed'].tensors[1], loaders['mixed'])
# metrics_dict_multiple[0.0]["gchurns_mixed"] = gchurns_mixed
# metrics_dict_multiple[0.0]["bchurns_mixed"] = bchurns_mixed
# metrics_dict_multiple[0.0]["accuracies_mixed"] = accuracies_mixed

# %%
gchurns_val, bchurns_val, accuracies_val = get_metrics(sets['val'].tensors[1], loaders['val'])
metrics_dict_multiple[0.0]["gchurns_val"] = gchurns_val
metrics_dict_multiple[0.0]["bchurns_val"] = bchurns_val
metrics_dict_multiple[0.0]["accuracies_val"] = accuracies_val
# Out:
# 100%|██████████| 32/32 [00:24<00:00,  1.32it/s]

# %% [markdown]
# Lambda = 0.3

# %%
#relabel based on threshold
confidence_threshold = 1.0

# gmm_labels = teacher_labels_mixed
lamda = 0.3

mixed_label = F.one_hot(sets['mixed'].tensors[1], num_classes=10)
gmm_labels = F.one_hot(teacher_labels_mixed, num_classes=10) * lamda + mixed_label * (1 - lamda)
# gmm_labels = torch.where(mixed_label != F.one_hot(y_mixed, num_classes=10), mixed_label, gmm_labels)


sets["teacher_unlab"] = torch.utils.data.TensorDataset(
    total_dict['x'][np.isin(total_dict['field'], ["unlab"])],
    unlab_teacherpred
)

sets["gmm"] = torch.utils.data.TensorDataset(
    torch.concat([
        sets['mixed'].tensors[0],
        sets['unlab'].tensors[0],
    ]),
    torch.concat([
        gmm_labels,
       unlab_teacherpred
    ]),
)
loaders['gmm'] = torch.utils.data.DataLoader(sets["gmm"], batch_size=batch_size, shuffle=False)

train_dist(
    name="student_unlab_model", 
    loader=loaders['gmm'],
)
student_gmm_model = CNN()
student_gmm_model.load_state_dict(torch.load("student_unlab_model.pth"))
student_gmm_model.eval()
None
# Out:
# Epoch [1/50], Loss: 0.5705
# Accuracy of the model on the test images: 81.60 %
# Validation error of the model on the test images: 0.5123
# Epoch [2/50], Loss: 0.4682
# Accuracy of the model on the test images: 83.98 %
# Validation error of the model on the test images: 0.4464
# Epoch [3/50], Loss: 0.4381
# Accuracy of the model on the test images: 85.05 %
# Validation error of the model on the test images: 0.4159
# Epoch [4/50], Loss: 0.3704
# Accuracy of the model on the test images: 86.11 %
# Validation error of the model on the test images: 0.3816
# Epoch [5/50], Loss: 0.3557
# Accuracy of the model on the test images: 86.99 %
# Validation error of the model on the test images: 0.3590
# Epoch [6/50], Loss: 0.3383
# Accuracy of the model on the test images: 87.83 %
# Validation error of the model on the test images: 0.3377
# Epoch [7/50], Loss: 0.3099
# Accuracy of the model on the test images: 88.24 %
# Validation error of the model on the test images: 0.3190
# Epoch [8/50], Loss: 0.3027
# Accuracy of the model on the test images: 88.74 %
# Validation error of the model on the test images: 0.3098
# Epoch [9/50], Loss: 0.2900
# Accuracy of the model on the test images: 89.35 %
# Validation error of the model on the test images: 0.2896
# Epoch [10/50], Loss: 0.2872
# Accuracy of the model on the test images: 89.52 %
# Validation error of the model on the test images: 0.2853
# Epoch [11/50], Loss: 0.2552
# Accuracy of the model on the test images: 90.17 %
# Validation error of the model on the test images: 0.2702
# Epoch [12/50], Loss: 0.2729
# Accuracy of the model on the test images: 90.26 %
# Validation error of the model on the test images: 0.2631
# Epoch [13/50], Loss: 0.2547
# Accuracy of the model on the test images: 90.76 %
# Validation error of the model on the test images: 0.2509
# Epoch [14/50], Loss: 0.2644
# Accuracy of the model on the test images: 91.29 %
# Validation error of the model on the test images: 0.2379
# Epoch [15/50], Loss: 0.2632
# Epoch [16/50], Loss: 0.2527
# Epoch [17/50], Loss: 0.2856
# Accuracy of the model on the test images: 91.66 %
# Validation error of the model on the test images: 0.2318
# Epoch [18/50], Loss: 0.2526
# Accuracy of the model on the test images: 91.73 %
# Validation error of the model on the test images: 0.2259
# Epoch [19/50], Loss: 0.2624
# Accuracy of the model on the test images: 92.10 %
# Validation error of the model on the test images: 0.2185
# Epoch [20/50], Loss: 0.2517
# Accuracy of the model on the test images: 92.20 %
# Validation error of the model on the test images: 0.2162
# Epoch [21/50], Loss: 0.2542
# Accuracy of the model on the test images: 92.39 %
# Validation error of the model on the test images: 0.2098
# Epoch [22/50], Loss: 0.2410
# Accuracy of the model on the test images: 92.74 %
# Validation error of the model on the test images: 0.2030
# Epoch [23/50], Loss: 0.2285
# Epoch [24/50], Loss: 0.2375
# Accuracy of the model on the test images: 93.02 %
# Validation error of the model on the test images: 0.1947
# Epoch [25/50], Loss: 0.2304
# Accuracy of the model on the test images: 93.14 %
# Validation error of the model on the test images: 0.1909
# Epoch [26/50], Loss: 0.2538
# Epoch [27/50], Loss: 0.2547
# Epoch [28/50], Loss: 0.2435
# Accuracy of the model on the test images: 93.45 %
# Validation error of the model on the test images: 0.1840
# Epoch [29/50], Loss: 0.2637
# Accuracy of the model on the test images: 93.46 %
# Validation error of the model on the test images: 0.1827
# Epoch [30/50], Loss: 0.2200
# Accuracy of the model on the test images: 93.72 %
# Validation error of the model on the test images: 0.1774
# Epoch [31/50], Loss: 0.2234
# Epoch [32/50], Loss: 0.2372
# Accuracy of the model on the test images: 94.07 %
# Validation error of the model on the test images: 0.1693
# Epoch [33/50], Loss: 0.2395
# Epoch [34/50], Loss: 0.2167
# Epoch [35/50], Loss: 0.2431
# Accuracy of the model on the test images: 94.14 %
# Validation error of the model on the test images: 0.1674
# Epoch [36/50], Loss: 0.2329
# Accuracy of the model on the test images: 94.19 %
# Validation error of the model on the test images: 0.1653
# Epoch [37/50], Loss: 0.2183
# Accuracy of the model on the test images: 94.24 %
# Validation error of the model on the test images: 0.1612
# Epoch [38/50], Loss: 0.2015
# Accuracy of the model on the test images: 94.47 %
# Validation error of the model on the test images: 0.1606
# Epoch [39/50], Loss: 0.1886
# Accuracy of the model on the test images: 94.46 %
# Validation error of the model on the test images: 0.1575
# Epoch [40/50], Loss: 0.2273
# Accuracy of the model on the test images: 94.69 %
# Validation error of the model on the test images: 0.1529
# Epoch [41/50], Loss: 0.2197
# Epoch [42/50], Loss: 0.2295
# Epoch [43/50], Loss: 0.2288
# Accuracy of the model on the test images: 94.75 %
# Validation error of the model on the test images: 0.1525
# Epoch [44/50], Loss: 0.2246
# Accuracy of the model on the test images: 95.01 %
# Validation error of the model on the test images: 0.1484
# Epoch [45/50], Loss: 0.2161
# Epoch [46/50], Loss: 0.2024
# Accuracy of the model on the test images: 95.08 %
# Validation error of the model on the test images: 0.1448
# Epoch [47/50], Loss: 0.2220
# Epoch [48/50], Loss: 0.2232
# Accuracy of the model on the test images: 95.25 %
# Validation error of the model on the test images: 0.1406
# Epoch [49/50], Loss: 0.2398
# Epoch [50/50], Loss: 0.2180

# %%
lamda = 0.3
distill_labels = F.one_hot(teacher_labels_mixed, num_classes=10) * (lamda) + F.one_hot(sets['mixed'].tensors[1], num_classes=10) * (1-lamda)

sets["distill"] = torch.utils.data.TensorDataset(
    sets['mixed'].tensors[0],
    distill_labels,
)

loaders['distill'] = torch.utils.data.DataLoader(sets['distill'], batch_size=batch_size, shuffle=False)

loader=loaders['distill']

train_dist(
    name="student_distil_model", 
    loader=loaders['distill'],
)
student_distil_model = CNN()
student_distil_model.load_state_dict(torch.load("student_distil_model.pth"))
student_distil_model.eval()
None
# Out:
# Epoch [1/50], Loss: 0.1476
# Accuracy of the model on the test images: 60.17 %
# Validation error of the model on the test images: 1.8058
# Epoch [2/50], Loss: 0.1614
# Accuracy of the model on the test images: 66.69 %
# Validation error of the model on the test images: 1.2854
# Epoch [3/50], Loss: 0.1274
# Accuracy of the model on the test images: 75.43 %
# Validation error of the model on the test images: 0.7963
# Epoch [4/50], Loss: 0.1142
# Accuracy of the model on the test images: 75.57 %
# Validation error of the model on the test images: 0.7864
# Epoch [5/50], Loss: 0.0963
# Accuracy of the model on the test images: 79.94 %
# Validation error of the model on the test images: 0.6299
# Epoch [6/50], Loss: 0.1125
# Accuracy of the model on the test images: 81.85 %
# Validation error of the model on the test images: 0.5442
# Epoch [7/50], Loss: 0.0711
# Epoch [8/50], Loss: 0.0684
# Accuracy of the model on the test images: 82.09 %
# Validation error of the model on the test images: 0.5219
# Epoch [9/50], Loss: 0.0777
# Accuracy of the model on the test images: 83.53 %
# Validation error of the model on the test images: 0.4867
# Epoch [10/50], Loss: 0.0727
# Accuracy of the model on the test images: 85.51 %
# Validation error of the model on the test images: 0.4118
# Epoch [11/50], Loss: 0.0866
# Accuracy of the model on the test images: 85.67 %
# Validation error of the model on the test images: 0.4086
# Epoch [12/50], Loss: 0.0711
# Epoch [13/50], Loss: 0.0616
# Accuracy of the model on the test images: 87.36 %
# Validation error of the model on the test images: 0.3579
# Epoch [14/50], Loss: 0.0627
# Accuracy of the model on the test images: 87.70 %
# Validation error of the model on the test images: 0.3463
# Epoch [15/50], Loss: 0.0545
# Accuracy of the model on the test images: 88.47 %
# Validation error of the model on the test images: 0.3173
# Epoch [16/50], Loss: 0.0598
# Epoch [17/50], Loss: 0.0711
# Epoch [18/50], Loss: 0.0551
# Epoch [19/50], Loss: 0.0700
# Accuracy of the model on the test images: 90.06 %
# Validation error of the model on the test images: 0.2735
# Epoch [20/50], Loss: 0.0634
# Epoch [21/50], Loss: 0.0464
# Accuracy of the model on the test images: 90.25 %
# Validation error of the model on the test images: 0.2699
# Epoch [22/50], Loss: 0.0675
# Epoch [23/50], Loss: 0.0483
# Epoch [24/50], Loss: 0.0455
# Epoch [25/50], Loss: 0.0649
# Accuracy of the model on the test images: 90.78 %
# Validation error of the model on the test images: 0.2496
# Epoch [26/50], Loss: 0.0643
# Accuracy of the model on the test images: 91.69 %
# Validation error of the model on the test images: 0.2255
# Epoch [27/50], Loss: 0.0496
# Epoch [28/50], Loss: 0.0518
# Accuracy of the model on the test images: 91.84 %
# Validation error of the model on the test images: 0.2234
# Epoch [29/50], Loss: 0.0590
# Accuracy of the model on the test images: 92.11 %
# Validation error of the model on the test images: 0.2102
# Epoch [30/50], Loss: 0.0546
# Accuracy of the model on the test images: 92.34 %
# Validation error of the model on the test images: 0.2032
# Epoch [31/50], Loss: 0.0469
# Epoch [32/50], Loss: 0.0565
# Epoch [33/50], Loss: 0.0537
# Epoch [34/50], Loss: 0.0487
# Accuracy of the model on the test images: 92.25 %
# Validation error of the model on the test images: 0.2027
# Epoch [35/50], Loss: 0.0545
# Accuracy of the model on the test images: 92.75 %
# Validation error of the model on the test images: 0.1911
# Epoch [36/50], Loss: 0.0536
# Accuracy of the model on the test images: 93.08 %
# Validation error of the model on the test images: 0.1854
# Epoch [37/50], Loss: 0.0771
# Accuracy of the model on the test images: 93.15 %
# Validation error of the model on the test images: 0.1773
# Epoch [38/50], Loss: 0.0723
# Accuracy of the model on the test images: 93.51 %
# Validation error of the model on the test images: 0.1689
# Epoch [39/50], Loss: 0.0593
# Epoch [40/50], Loss: 0.0431
# Epoch [41/50], Loss: 0.0378
# Epoch [42/50], Loss: 0.0390
# Accuracy of the model on the test images: 93.74 %
# Validation error of the model on the test images: 0.1645
# Epoch [43/50], Loss: 0.0451
# Accuracy of the model on the test images: 93.75 %
# Validation error of the model on the test images: 0.1613
# Epoch [44/50], Loss: 0.0540
# Epoch [45/50], Loss: 0.0654
# Accuracy of the model on the test images: 93.93 %
# Validation error of the model on the test images: 0.1589
# Epoch [46/50], Loss: 0.0536
# Epoch [47/50], Loss: 0.0380
# Accuracy of the model on the test images: 94.12 %
# Validation error of the model on the test images: 0.1539
# Epoch [48/50], Loss: 0.0385
# Accuracy of the model on the test images: 94.65 %
# Validation error of the model on the test images: 0.1388
# Epoch [49/50], Loss: 0.0545
# Epoch [50/50], Loss: 0.0524
# Accuracy of the model on the test images: 94.95 %
# Validation error of the model on the test images: 0.1305

# %%
# gchurns_mixed, bchurns_mixed, accuracies_mixed = get_metrics(sets['mixed'].tensors[1], loaders['mixed'])
# metrics_dict_multiple[0.3]["gchurns_mixed"] = gchurns_mixed
# metrics_dict_multiple[0.3]["bchurns_mixed"] = bchurns_mixed
# metrics_dict_multiple[0.3]["accuracies_mixed"] = accuracies_mixed

gchurns_val, bchurns_val, accuracies_val = get_metrics(sets['val'].tensors[1], loaders['val'])
metrics_dict_multiple[0.3]["gchurns_val"] = gchurns_val
metrics_dict_multiple[0.3]["bchurns_val"] = bchurns_val
metrics_dict_multiple[0.3]["accuracies_val"] = accuracies_val
# Out:
# 100%|██████████| 32/32 [00:20<00:00,  1.57it/s]

# %% [markdown]
# ### Lambda = 0.5

# %%
#relabel based on threshold
confidence_threshold = 1.0

# gmm_labels = teacher_labels_mixed
lamda = 0.5

mixed_label = F.one_hot(sets['mixed'].tensors[1], num_classes=10)
gmm_labels = F.one_hot(teacher_labels_mixed, num_classes=10) * lamda + mixed_label * (1 - lamda)
# gmm_labels = torch.where(mixed_label != F.one_hot(y_mixed, num_classes=10), mixed_label, gmm_labels)


sets["teacher_unlab"] = torch.utils.data.TensorDataset(
    total_dict['x'][np.isin(total_dict['field'], ["unlab"])],
    unlab_teacherpred
)

sets["gmm"] = torch.utils.data.TensorDataset(
    torch.concat([
        sets['mixed'].tensors[0],
        sets['unlab'].tensors[0],
    ]),
    torch.concat([
        gmm_labels,
       unlab_teacherpred
    ]),
)
loaders['gmm'] = torch.utils.data.DataLoader(sets["gmm"], batch_size=batch_size, shuffle=False)


train_dist(
    name="student_unlab_model", 
    loader=loaders['gmm'],
)
student_gmm_model = CNN()
student_gmm_model.load_state_dict(torch.load("student_unlab_model.pth"))
student_gmm_model.eval()
None
# Out:
# Epoch [1/50], Loss: 0.5222
# Accuracy of the model on the test images: 82.71 %
# Validation error of the model on the test images: 0.4883
# Epoch [2/50], Loss: 0.4665
# Accuracy of the model on the test images: 84.59 %
# Validation error of the model on the test images: 0.4318
# Epoch [3/50], Loss: 0.3773
# Accuracy of the model on the test images: 86.14 %
# Validation error of the model on the test images: 0.3854
# Epoch [4/50], Loss: 0.3771
# Accuracy of the model on the test images: 87.30 %
# Validation error of the model on the test images: 0.3581
# Epoch [5/50], Loss: 0.3373
# Accuracy of the model on the test images: 88.22 %
# Validation error of the model on the test images: 0.3332
# Epoch [6/50], Loss: 0.3132
# Accuracy of the model on the test images: 89.28 %
# Validation error of the model on the test images: 0.3039
# Epoch [7/50], Loss: 0.3095
# Accuracy of the model on the test images: 89.29 %
# Validation error of the model on the test images: 0.2999
# Epoch [8/50], Loss: 0.2660
# Accuracy of the model on the test images: 90.28 %
# Validation error of the model on the test images: 0.2759
# Epoch [9/50], Loss: 0.2657
# Accuracy of the model on the test images: 90.57 %
# Validation error of the model on the test images: 0.2653
# Epoch [10/50], Loss: 0.2683
# Accuracy of the model on the test images: 90.67 %
# Validation error of the model on the test images: 0.2615
# Epoch [11/50], Loss: 0.2400
# Accuracy of the model on the test images: 91.04 %
# Validation error of the model on the test images: 0.2527
# Epoch [12/50], Loss: 0.2570
# Accuracy of the model on the test images: 91.42 %
# Validation error of the model on the test images: 0.2416
# Epoch [13/50], Loss: 0.2313
# Accuracy of the model on the test images: 91.87 %
# Validation error of the model on the test images: 0.2320
# Epoch [14/50], Loss: 0.2435
# Accuracy of the model on the test images: 92.04 %
# Validation error of the model on the test images: 0.2233
# Epoch [15/50], Loss: 0.2557
# Accuracy of the model on the test images: 92.10 %
# Validation error of the model on the test images: 0.2223
# Epoch [16/50], Loss: 0.2181
# Accuracy of the model on the test images: 92.44 %
# Validation error of the model on the test images: 0.2176
# Epoch [17/50], Loss: 0.2668
# Accuracy of the model on the test images: 92.57 %
# Validation error of the model on the test images: 0.2113
# Epoch [18/50], Loss: 0.2154
# Accuracy of the model on the test images: 92.63 %
# Validation error of the model on the test images: 0.2090
# Epoch [19/50], Loss: 0.2543
# Accuracy of the model on the test images: 92.78 %
# Validation error of the model on the test images: 0.2061
# Epoch [20/50], Loss: 0.2351
# Accuracy of the model on the test images: 93.01 %
# Validation error of the model on the test images: 0.2007
# Epoch [21/50], Loss: 0.2276
# Accuracy of the model on the test images: 93.34 %
# Validation error of the model on the test images: 0.1912
# Epoch [22/50], Loss: 0.2333
# Accuracy of the model on the test images: 93.46 %
# Validation error of the model on the test images: 0.1897
# Epoch [23/50], Loss: 0.2264
# Epoch [24/50], Loss: 0.2156
# Accuracy of the model on the test images: 93.86 %
# Validation error of the model on the test images: 0.1802
# Epoch [25/50], Loss: 0.2310
# Accuracy of the model on the test images: 93.75 %
# Validation error of the model on the test images: 0.1786
# Epoch [26/50], Loss: 0.2427
# Accuracy of the model on the test images: 93.94 %
# Validation error of the model on the test images: 0.1761
# Epoch [27/50], Loss: 0.2255
# Epoch [28/50], Loss: 0.2492
# Accuracy of the model on the test images: 94.20 %
# Validation error of the model on the test images: 0.1707
# Epoch [29/50], Loss: 0.2378
# Accuracy of the model on the test images: 94.34 %
# Validation error of the model on the test images: 0.1671
# Epoch [30/50], Loss: 0.2397
# Epoch [31/50], Loss: 0.2325
# Epoch [32/50], Loss: 0.2094
# Accuracy of the model on the test images: 94.65 %
# Validation error of the model on the test images: 0.1600
# Epoch [33/50], Loss: 0.2473
# Accuracy of the model on the test images: 94.72 %
# Validation error of the model on the test images: 0.1593
# Epoch [34/50], Loss: 0.2252
# Accuracy of the model on the test images: 94.74 %
# Validation error of the model on the test images: 0.1590
# Epoch [35/50], Loss: 0.2243
# Accuracy of the model on the test images: 94.73 %
# Validation error of the model on the test images: 0.1567
# Epoch [36/50], Loss: 0.2370
# Accuracy of the model on the test images: 94.87 %
# Validation error of the model on the test images: 0.1549
# Epoch [37/50], Loss: 0.2399
# Accuracy of the model on the test images: 95.01 %
# Validation error of the model on the test images: 0.1525
# Epoch [38/50], Loss: 0.2049
# Epoch [39/50], Loss: 0.2008
# Accuracy of the model on the test images: 95.12 %
# Validation error of the model on the test images: 0.1501
# Epoch [40/50], Loss: 0.2199
# Accuracy of the model on the test images: 95.26 %
# Validation error of the model on the test images: 0.1448
# Epoch [41/50], Loss: 0.2128
# Epoch [42/50], Loss: 0.2294
# Epoch [43/50], Loss: 0.1955
# Accuracy of the model on the test images: 95.44 %
# Validation error of the model on the test images: 0.1431
# Epoch [44/50], Loss: 0.2170
# Accuracy of the model on the test images: 95.44 %
# Validation error of the model on the test images: 0.1428
# Epoch [45/50], Loss: 0.2034
# Epoch [46/50], Loss: 0.2089
# Accuracy of the model on the test images: 95.63 %
# Validation error of the model on the test images: 0.1366
# Epoch [47/50], Loss: 0.2079
# Epoch [48/50], Loss: 0.2388
# Accuracy of the model on the test images: 95.68 %
# Validation error of the model on the test images: 0.1348
# Epoch [49/50], Loss: 0.2301
# Epoch [50/50], Loss: 0.2152
# Accuracy of the model on the test images: 95.92 %
# Validation error of the model on the test images: 0.1327

# %%
lamda = 0.5
distill_labels = F.one_hot(teacher_labels_mixed, num_classes=10) * (lamda) + F.one_hot(sets['mixed'].tensors[1], num_classes=10) * (1-lamda)

sets["distill"] = torch.utils.data.TensorDataset(
    sets['mixed'].tensors[0],
    distill_labels,
)

loaders['distill'] = torch.utils.data.DataLoader(sets['distill'], batch_size=batch_size, shuffle=False)

loader=loaders['distill']

train_dist(
    name="student_distil_model", 
    loader=loaders['distill'],
)
student_distil_model = CNN()
student_distil_model.load_state_dict(torch.load("student_distil_model.pth"))
student_distil_model.eval()
None
# Out:
# Epoch [1/50], Loss: 0.1659
# Accuracy of the model on the test images: 65.42 %
# Validation error of the model on the test images: 1.3020
# Epoch [2/50], Loss: 0.1712
# Accuracy of the model on the test images: 71.35 %
# Validation error of the model on the test images: 1.0067
# Epoch [3/50], Loss: 0.1575
# Accuracy of the model on the test images: 77.77 %
# Validation error of the model on the test images: 0.7105
# Epoch [4/50], Loss: 0.1341
# Accuracy of the model on the test images: 77.92 %
# Validation error of the model on the test images: 0.6812
# Epoch [5/50], Loss: 0.1072
# Accuracy of the model on the test images: 81.47 %
# Validation error of the model on the test images: 0.5641
# Epoch [6/50], Loss: 0.1105
# Accuracy of the model on the test images: 84.38 %
# Validation error of the model on the test images: 0.4505
# Epoch [7/50], Loss: 0.1041
# Epoch [8/50], Loss: 0.0788
# Accuracy of the model on the test images: 85.73 %
# Validation error of the model on the test images: 0.4179
# Epoch [9/50], Loss: 0.0980
# Epoch [10/50], Loss: 0.0834
# Accuracy of the model on the test images: 86.55 %
# Validation error of the model on the test images: 0.3851
# Epoch [11/50], Loss: 0.1017
# Epoch [12/50], Loss: 0.0826
# Epoch [13/50], Loss: 0.0680
# Accuracy of the model on the test images: 89.43 %
# Validation error of the model on the test images: 0.2991
# Epoch [14/50], Loss: 0.0792
# Epoch [15/50], Loss: 0.0728
# Epoch [16/50], Loss: 0.0647
# Epoch [17/50], Loss: 0.0785
# Accuracy of the model on the test images: 89.51 %
# Validation error of the model on the test images: 0.2937
# Epoch [18/50], Loss: 0.0611
# Epoch [19/50], Loss: 0.0768
# Accuracy of the model on the test images: 91.10 %
# Validation error of the model on the test images: 0.2469
# Epoch [20/50], Loss: 0.0619
# Epoch [21/50], Loss: 0.0466
# Epoch [22/50], Loss: 0.0712
# Accuracy of the model on the test images: 91.00 %
# Validation error of the model on the test images: 0.2419
# Epoch [23/50], Loss: 0.0589
# Epoch [24/50], Loss: 0.0583
# Epoch [25/50], Loss: 0.0680
# Epoch [26/50], Loss: 0.0795
# Accuracy of the model on the test images: 91.76 %
# Validation error of the model on the test images: 0.2292
# Epoch [27/50], Loss: 0.0731
# Accuracy of the model on the test images: 91.65 %
# Validation error of the model on the test images: 0.2267
# Epoch [28/50], Loss: 0.0515
# Accuracy of the model on the test images: 91.93 %
# Validation error of the model on the test images: 0.2196
# Epoch [29/50], Loss: 0.0691
# Accuracy of the model on the test images: 91.88 %
# Validation error of the model on the test images: 0.2184
# Epoch [30/50], Loss: 0.0644
# Accuracy of the model on the test images: 92.35 %
# Validation error of the model on the test images: 0.2096
# Epoch [31/50], Loss: 0.0661
# Accuracy of the model on the test images: 92.29 %
# Validation error of the model on the test images: 0.2083
# Epoch [32/50], Loss: 0.0711
# Accuracy of the model on the test images: 92.92 %
# Validation error of the model on the test images: 0.1910
# Epoch [33/50], Loss: 0.0647
# Epoch [34/50], Loss: 0.0545
# Epoch [35/50], Loss: 0.0705
# Accuracy of the model on the test images: 92.89 %
# Validation error of the model on the test images: 0.1884
# Epoch [36/50], Loss: 0.0556
# Accuracy of the model on the test images: 93.20 %
# Validation error of the model on the test images: 0.1826
# Epoch [37/50], Loss: 0.0815
# Accuracy of the model on the test images: 93.42 %
# Validation error of the model on the test images: 0.1767
# Epoch [38/50], Loss: 0.0814
# Accuracy of the model on the test images: 93.81 %
# Validation error of the model on the test images: 0.1657
# Epoch [39/50], Loss: 0.0570
# Accuracy of the model on the test images: 94.01 %
# Validation error of the model on the test images: 0.1600
# Epoch [40/50], Loss: 0.0534
# Epoch [41/50], Loss: 0.0603
# Epoch [42/50], Loss: 0.0536
# Accuracy of the model on the test images: 94.32 %
# Validation error of the model on the test images: 0.1501
# Epoch [43/50], Loss: 0.0547
# Epoch [44/50], Loss: 0.0665
# Accuracy of the model on the test images: 94.60 %
# Validation error of the model on the test images: 0.1482
# Epoch [45/50], Loss: 0.0707
# Epoch [46/50], Loss: 0.0879
# Epoch [47/50], Loss: 0.0532
# Epoch [48/50], Loss: 0.0469
# Accuracy of the model on the test images: 94.89 %
# Validation error of the model on the test images: 0.1412
# Epoch [49/50], Loss: 0.0517
# Epoch [50/50], Loss: 0.0567
# Accuracy of the model on the test images: 94.81 %
# Validation error of the model on the test images: 0.1389

# %%
# gchurns_mixed, bchurns_mixed, accuracies_mixed = get_metrics(sets['mixed'].tensors[1], loaders['mixed'])
# metrics_dict_multiple[0.5]["gchurns_mixed"] = gchurns_mixed
# metrics_dict_multiple[0.5]["bchurns_mixed"] = bchurns_mixed
# metrics_dict_multiple[0.5]["accuracies_mixed"] = accuracies_mixed

gchurns_val, bchurns_val, accuracies_val = get_metrics(sets['val'].tensors[1], loaders['val'])
metrics_dict_multiple[0.5]["gchurns_val"] = gchurns_val
metrics_dict_multiple[0.5]["bchurns_val"] = bchurns_val
metrics_dict_multiple[0.5]["accuracies_val"] = accuracies_val
# Out:
# 100%|██████████| 32/32 [00:24<00:00,  1.33it/s]

# %% [markdown]
# ### Lambda = 0.7

# %%
#relabel based on threshold
confidence_threshold = 1.0

# gmm_labels = teacher_labels_mixed
lamda = 0.7

mixed_label = F.one_hot(sets['mixed'].tensors[1], num_classes=10)
gmm_labels = F.one_hot(teacher_labels_mixed, num_classes=10) * lamda + mixed_label * (1 - lamda)
# gmm_labels = torch.where(mixed_label != F.one_hot(y_mixed, num_classes=10), mixed_label, gmm_labels)

sets["teacher_unlab"] = torch.utils.data.TensorDataset(
    total_dict['x'][np.isin(total_dict['field'], ["unlab"])],
    unlab_teacherpred
)

sets["gmm"] = torch.utils.data.TensorDataset(
    torch.concat([
        sets['mixed'].tensors[0],
        sets['unlab'].tensors[0],
    ]),
    torch.concat([
        gmm_labels,
       unlab_teacherpred
    ]),
)
loaders['gmm'] = torch.utils.data.DataLoader(sets["gmm"], batch_size=batch_size, shuffle=False)

train_dist(
    name="student_unlab_model", 
    loader=loaders['gmm'],
)
student_gmm_model = CNN()
student_gmm_model.load_state_dict(torch.load("student_unlab_model.pth"))
student_gmm_model.eval()
None
# Out:
# Epoch [1/50], Loss: 0.5528
# Accuracy of the model on the test images: 82.68 %
# Validation error of the model on the test images: 0.4905
# Epoch [2/50], Loss: 0.4348
# Accuracy of the model on the test images: 85.19 %
# Validation error of the model on the test images: 0.4188
# Epoch [3/50], Loss: 0.4035
# Accuracy of the model on the test images: 86.93 %
# Validation error of the model on the test images: 0.3693
# Epoch [4/50], Loss: 0.3402
# Accuracy of the model on the test images: 88.27 %
# Validation error of the model on the test images: 0.3342
# Epoch [5/50], Loss: 0.3149
# Accuracy of the model on the test images: 89.06 %
# Validation error of the model on the test images: 0.3125
# Epoch [6/50], Loss: 0.3094
# Accuracy of the model on the test images: 89.81 %
# Validation error of the model on the test images: 0.2946
# Epoch [7/50], Loss: 0.2853
# Accuracy of the model on the test images: 90.37 %
# Validation error of the model on the test images: 0.2776
# Epoch [8/50], Loss: 0.2732
# Accuracy of the model on the test images: 90.61 %
# Validation error of the model on the test images: 0.2675
# Epoch [9/50], Loss: 0.2677
# Accuracy of the model on the test images: 91.26 %
# Validation error of the model on the test images: 0.2538
# Epoch [10/50], Loss: 0.2591
# Accuracy of the model on the test images: 91.55 %
# Validation error of the model on the test images: 0.2471
# Epoch [11/50], Loss: 0.2180
# Accuracy of the model on the test images: 91.92 %
# Validation error of the model on the test images: 0.2369
# Epoch [12/50], Loss: 0.2603
# Accuracy of the model on the test images: 92.07 %
# Validation error of the model on the test images: 0.2310
# Epoch [13/50], Loss: 0.2509
# Accuracy of the model on the test images: 92.47 %
# Validation error of the model on the test images: 0.2204
# Epoch [14/50], Loss: 0.2387
# Accuracy of the model on the test images: 92.67 %
# Validation error of the model on the test images: 0.2146
# Epoch [15/50], Loss: 0.2492
# Accuracy of the model on the test images: 92.91 %
# Validation error of the model on the test images: 0.2103
# Epoch [16/50], Loss: 0.2063
# Accuracy of the model on the test images: 92.99 %
# Validation error of the model on the test images: 0.2101
# Epoch [17/50], Loss: 0.2452
# Accuracy of the model on the test images: 93.42 %
# Validation error of the model on the test images: 0.1979
# Epoch [18/50], Loss: 0.2164
# Accuracy of the model on the test images: 93.46 %
# Validation error of the model on the test images: 0.1956
# Epoch [19/50], Loss: 0.2519
# Accuracy of the model on the test images: 93.69 %
# Validation error of the model on the test images: 0.1914
# Epoch [20/50], Loss: 0.2256
# Accuracy of the model on the test images: 93.74 %
# Validation error of the model on the test images: 0.1880
# Epoch [21/50], Loss: 0.2229
# Accuracy of the model on the test images: 93.99 %
# Validation error of the model on the test images: 0.1833
# Epoch [22/50], Loss: 0.2283
# Accuracy of the model on the test images: 94.28 %
# Validation error of the model on the test images: 0.1778
# Epoch [23/50], Loss: 0.2192
# Epoch [24/50], Loss: 0.2215
# Accuracy of the model on the test images: 94.49 %
# Validation error of the model on the test images: 0.1705
# Epoch [25/50], Loss: 0.2193
# Accuracy of the model on the test images: 94.58 %
# Validation error of the model on the test images: 0.1672
# Epoch [26/50], Loss: 0.2381
# Accuracy of the model on the test images: 94.58 %
# Validation error of the model on the test images: 0.1670
# Epoch [27/50], Loss: 0.2165
# Accuracy of the model on the test images: 94.64 %
# Validation error of the model on the test images: 0.1666
# Epoch [28/50], Loss: 0.2076
# Accuracy of the model on the test images: 94.81 %
# Validation error of the model on the test images: 0.1643
# Epoch [29/50], Loss: 0.2184
# Accuracy of the model on the test images: 94.84 %
# Validation error of the model on the test images: 0.1614
# Epoch [30/50], Loss: 0.2277
# Accuracy of the model on the test images: 94.87 %
# Validation error of the model on the test images: 0.1602
# Epoch [31/50], Loss: 0.2240
# Accuracy of the model on the test images: 94.97 %
# Validation error of the model on the test images: 0.1586
# Epoch [32/50], Loss: 0.2033
# Accuracy of the model on the test images: 95.22 %
# Validation error of the model on the test images: 0.1525
# Epoch [33/50], Loss: 0.2401
# Accuracy of the model on the test images: 95.40 %
# Validation error of the model on the test images: 0.1510
# Epoch [34/50], Loss: 0.1981
# Epoch [35/50], Loss: 0.2482
# Epoch [36/50], Loss: 0.2271
# Accuracy of the model on the test images: 95.55 %
# Validation error of the model on the test images: 0.1451
# Epoch [37/50], Loss: 0.2306
# Accuracy of the model on the test images: 95.62 %
# Validation error of the model on the test images: 0.1443
# Epoch [38/50], Loss: 0.2053
# Epoch [39/50], Loss: 0.1899
# Accuracy of the model on the test images: 95.75 %
# Validation error of the model on the test images: 0.1417
# Epoch [40/50], Loss: 0.2201
# Accuracy of the model on the test images: 95.78 %
# Validation error of the model on the test images: 0.1401
# Epoch [41/50], Loss: 0.2058
# Epoch [42/50], Loss: 0.2157
# Epoch [43/50], Loss: 0.2056
# Accuracy of the model on the test images: 95.85 %
# Validation error of the model on the test images: 0.1378
# Epoch [44/50], Loss: 0.2166
# Accuracy of the model on the test images: 95.84 %
# Validation error of the model on the test images: 0.1371
# Epoch [45/50], Loss: 0.2149
# Accuracy of the model on the test images: 95.95 %
# Validation error of the model on the test images: 0.1363
# Epoch [46/50], Loss: 0.2210
# Accuracy of the model on the test images: 96.11 %
# Validation error of the model on the test images: 0.1330
# Epoch [47/50], Loss: 0.2145
# Epoch [48/50], Loss: 0.2184
# Accuracy of the model on the test images: 96.29 %
# Validation error of the model on the test images: 0.1297
# Epoch [49/50], Loss: 0.2276
# Epoch [50/50], Loss: 0.2072
# Accuracy of the model on the test images: 96.32 %
# Validation error of the model on the test images: 0.1289

# %%
lamda = 0.7
distill_labels = F.one_hot(teacher_labels_mixed, num_classes=10) * (lamda) + F.one_hot(sets['mixed'].tensors[1], num_classes=10) * (1-lamda)

sets["distill"] = torch.utils.data.TensorDataset(
    sets['mixed'].tensors[0],
    distill_labels,
)

loaders['distill'] = torch.utils.data.DataLoader(sets['distill'], batch_size=batch_size, shuffle=False)

loader=loaders['distill']

train_dist(
    name="student_distil_model", 
    loader=loaders['distill'],
)
student_distil_model = CNN()
student_distil_model.load_state_dict(torch.load("student_distil_model.pth"))
student_distil_model.eval()
None
# Out:
# Epoch [1/50], Loss: 0.1798
# Accuracy of the model on the test images: 71.32 %
# Validation error of the model on the test images: 0.9996
# Epoch [2/50], Loss: 0.1805
# Accuracy of the model on the test images: 75.77 %
# Validation error of the model on the test images: 0.7670
# Epoch [3/50], Loss: 0.1484
# Accuracy of the model on the test images: 79.33 %
# Validation error of the model on the test images: 0.6205
# Epoch [4/50], Loss: 0.1304
# Accuracy of the model on the test images: 81.25 %
# Validation error of the model on the test images: 0.5495
# Epoch [5/50], Loss: 0.1397
# Accuracy of the model on the test images: 84.85 %
# Validation error of the model on the test images: 0.4508
# Epoch [6/50], Loss: 0.1350
# Accuracy of the model on the test images: 84.75 %
# Validation error of the model on the test images: 0.4324
# Epoch [7/50], Loss: 0.1127
# Epoch [8/50], Loss: 0.0757
# Accuracy of the model on the test images: 86.82 %
# Validation error of the model on the test images: 0.3812
# Epoch [9/50], Loss: 0.1035
# Accuracy of the model on the test images: 87.02 %
# Validation error of the model on the test images: 0.3756
# Epoch [10/50], Loss: 0.0917
# Accuracy of the model on the test images: 87.63 %
# Validation error of the model on the test images: 0.3537
# Epoch [11/50], Loss: 0.1095
# Accuracy of the model on the test images: 88.22 %
# Validation error of the model on the test images: 0.3467
# Epoch [12/50], Loss: 0.0829
# Epoch [13/50], Loss: 0.0876
# Accuracy of the model on the test images: 90.43 %
# Validation error of the model on the test images: 0.2710
# Epoch [14/50], Loss: 0.0652
# Epoch [15/50], Loss: 0.0698
# Epoch [16/50], Loss: 0.0746
# Epoch [17/50], Loss: 0.0860
# Epoch [18/50], Loss: 0.0660
# Accuracy of the model on the test images: 91.36 %
# Validation error of the model on the test images: 0.2461
# Epoch [19/50], Loss: 0.0882
# Accuracy of the model on the test images: 91.89 %
# Validation error of the model on the test images: 0.2376
# Epoch [20/50], Loss: 0.0730
# Accuracy of the model on the test images: 91.72 %
# Validation error of the model on the test images: 0.2291
# Epoch [21/50], Loss: 0.0491
# Accuracy of the model on the test images: 92.00 %
# Validation error of the model on the test images: 0.2278
# Epoch [22/50], Loss: 0.0678
# Accuracy of the model on the test images: 92.35 %
# Validation error of the model on the test images: 0.2122
# Epoch [23/50], Loss: 0.0591
# Epoch [24/50], Loss: 0.0596
# Epoch [25/50], Loss: 0.0708
# Accuracy of the model on the test images: 92.51 %
# Validation error of the model on the test images: 0.2112
# Epoch [26/50], Loss: 0.0714
# Accuracy of the model on the test images: 92.82 %
# Validation error of the model on the test images: 0.2032
# Epoch [27/50], Loss: 0.0499
# Accuracy of the model on the test images: 93.24 %
# Validation error of the model on the test images: 0.1895
# Epoch [28/50], Loss: 0.0485
# Epoch [29/50], Loss: 0.0661
# Epoch [30/50], Loss: 0.0650
# Accuracy of the model on the test images: 93.82 %
# Validation error of the model on the test images: 0.1721
# Epoch [31/50], Loss: 0.0723
# Accuracy of the model on the test images: 94.18 %
# Validation error of the model on the test images: 0.1635
# Epoch [32/50], Loss: 0.0656
# Epoch [33/50], Loss: 0.0592
# Epoch [34/50], Loss: 0.0657
# Epoch [35/50], Loss: 0.0683
# Accuracy of the model on the test images: 94.22 %
# Validation error of the model on the test images: 0.1616
# Epoch [36/50], Loss: 0.0589
# Accuracy of the model on the test images: 94.44 %
# Validation error of the model on the test images: 0.1534
# Epoch [37/50], Loss: 0.0818
# Epoch [38/50], Loss: 0.0652
# Accuracy of the model on the test images: 94.67 %
# Validation error of the model on the test images: 0.1495
# Epoch [39/50], Loss: 0.0787
# Epoch [40/50], Loss: 0.0463
# Accuracy of the model on the test images: 95.21 %
# Validation error of the model on the test images: 0.1365
# Epoch [41/50], Loss: 0.0550
# Epoch [42/50], Loss: 0.0388
# Epoch [43/50], Loss: 0.0511
# Accuracy of the model on the test images: 95.31 %
# Validation error of the model on the test images: 0.1360
# Epoch [44/50], Loss: 0.0632
# Accuracy of the model on the test images: 95.41 %
# Validation error of the model on the test images: 0.1298
# Epoch [45/50], Loss: 0.0759
# Epoch [46/50], Loss: 0.0932
# Accuracy of the model on the test images: 95.70 %
# Validation error of the model on the test images: 0.1262
# Epoch [47/50], Loss: 0.0623
# Epoch [48/50], Loss: 0.0448
# Epoch [49/50], Loss: 0.0487
# Accuracy of the model on the test images: 95.54 %
# Validation error of the model on the test images: 0.1255
# Epoch [50/50], Loss: 0.0725
# Accuracy of the model on the test images: 95.91 %
# Validation error of the model on the test images: 0.1193

# %%
# gchurns_mixed, bchurns_mixed, accuracies_mixed = get_metrics(sets['mixed'].tensors[1], loaders['mixed'])
# metrics_dict_multiple[0.7]["gchurns_mixed"] = gchurns_mixed
# metrics_dict_multiple[0.7]["bchurns_mixed"] = bchurns_mixed
# metrics_dict_multiple[0.7]["accuracies_mixed"] = accuracies_mixed

gchurns_val, bchurns_val, accuracies_val = get_metrics(sets['val'].tensors[1], loaders['val'])
metrics_dict_multiple[0.7]["gchurns_val"] = gchurns_val
metrics_dict_multiple[0.7]["bchurns_val"] = bchurns_val
metrics_dict_multiple[0.7]["accuracies_val"] = accuracies_val
# Out:
# 100%|██████████| 32/32 [00:21<00:00,  1.50it/s]

# %% [markdown]
# ### Lambda = 0.9

# %%
#relabel based on threshold
confidence_threshold = 1.0

# gmm_labels = teacher_labels_mixed
lamda = 0.9

mixed_label = F.one_hot(sets['mixed'].tensors[1], num_classes=10)
gmm_labels = F.one_hot(teacher_labels_mixed, num_classes=10) * lamda + mixed_label * (1 - lamda)
# gmm_labels = torch.where(mixed_label != F.one_hot(y_mixed, num_classes=10), mixed_label, gmm_labels)

sets["teacher_unlab"] = torch.utils.data.TensorDataset(
    total_dict['x'][np.isin(total_dict['field'], ["unlab"])],
    unlab_teacherpred
)

sets["gmm"] = torch.utils.data.TensorDataset(
    torch.concat([
        sets['mixed'].tensors[0],
        sets['unlab'].tensors[0],
    ]),
    torch.concat([
        gmm_labels,
       unlab_teacherpred
    ]),
)
loaders['gmm'] = torch.utils.data.DataLoader(sets["gmm"], batch_size=batch_size, shuffle=False)
train_dist(
    name="student_unlab_model", 
    loader=loaders['gmm'],
)
student_gmm_model = CNN()
student_gmm_model.load_state_dict(torch.load("student_unlab_model.pth"))
student_gmm_model.eval()
None
# Out:
# Epoch [1/50], Loss: 0.5274
# Accuracy of the model on the test images: 82.86 %
# Validation error of the model on the test images: 0.4806
# Epoch [2/50], Loss: 0.4346
# Accuracy of the model on the test images: 85.80 %
# Validation error of the model on the test images: 0.3984
# Epoch [3/50], Loss: 0.3884
# Accuracy of the model on the test images: 87.34 %
# Validation error of the model on the test images: 0.3521
# Epoch [4/50], Loss: 0.3400
# Accuracy of the model on the test images: 88.39 %
# Validation error of the model on the test images: 0.3269
# Epoch [5/50], Loss: 0.3362
# Accuracy of the model on the test images: 89.40 %
# Validation error of the model on the test images: 0.3015
# Epoch [6/50], Loss: 0.2872
# Accuracy of the model on the test images: 89.96 %
# Validation error of the model on the test images: 0.2864
# Epoch [7/50], Loss: 0.2963
# Accuracy of the model on the test images: 90.39 %
# Validation error of the model on the test images: 0.2707
# Epoch [8/50], Loss: 0.2690
# Accuracy of the model on the test images: 90.90 %
# Validation error of the model on the test images: 0.2590
# Epoch [9/50], Loss: 0.2643
# Accuracy of the model on the test images: 91.35 %
# Validation error of the model on the test images: 0.2472
# Epoch [10/50], Loss: 0.2530
# Accuracy of the model on the test images: 91.47 %
# Validation error of the model on the test images: 0.2400
# Epoch [11/50], Loss: 0.2206
# Accuracy of the model on the test images: 92.02 %
# Validation error of the model on the test images: 0.2285
# Epoch [12/50], Loss: 0.2587
# Accuracy of the model on the test images: 92.22 %
# Validation error of the model on the test images: 0.2234
# Epoch [13/50], Loss: 0.2457
# Accuracy of the model on the test images: 92.65 %
# Validation error of the model on the test images: 0.2121
# Epoch [14/50], Loss: 0.2425
# Accuracy of the model on the test images: 92.70 %
# Validation error of the model on the test images: 0.2093
# Epoch [15/50], Loss: 0.2465
# Accuracy of the model on the test images: 93.07 %
# Validation error of the model on the test images: 0.2019
# Epoch [16/50], Loss: 0.2143
# Epoch [17/50], Loss: 0.2503
# Accuracy of the model on the test images: 93.55 %
# Validation error of the model on the test images: 0.1902
# Epoch [18/50], Loss: 0.2234
# Accuracy of the model on the test images: 93.44 %
# Validation error of the model on the test images: 0.1900
# Epoch [19/50], Loss: 0.2342
# Accuracy of the model on the test images: 93.58 %
# Validation error of the model on the test images: 0.1850
# Epoch [20/50], Loss: 0.2216
# Accuracy of the model on the test images: 93.80 %
# Validation error of the model on the test images: 0.1804
# Epoch [21/50], Loss: 0.2263
# Accuracy of the model on the test images: 93.99 %
# Validation error of the model on the test images: 0.1754
# Epoch [22/50], Loss: 0.2275
# Accuracy of the model on the test images: 94.27 %
# Validation error of the model on the test images: 0.1714
# Epoch [23/50], Loss: 0.2107
# Accuracy of the model on the test images: 94.29 %
# Validation error of the model on the test images: 0.1682
# Epoch [24/50], Loss: 0.2176
# Accuracy of the model on the test images: 94.40 %
# Validation error of the model on the test images: 0.1645
# Epoch [25/50], Loss: 0.2227
# Accuracy of the model on the test images: 94.66 %
# Validation error of the model on the test images: 0.1603
# Epoch [26/50], Loss: 0.2182
# Accuracy of the model on the test images: 94.66 %
# Validation error of the model on the test images: 0.1577
# Epoch [27/50], Loss: 0.2212
# Epoch [28/50], Loss: 0.2166
# Accuracy of the model on the test images: 94.98 %
# Validation error of the model on the test images: 0.1547
# Epoch [29/50], Loss: 0.2204
# Accuracy of the model on the test images: 95.02 %
# Validation error of the model on the test images: 0.1519
# Epoch [30/50], Loss: 0.2328
# Accuracy of the model on the test images: 95.05 %
# Validation error of the model on the test images: 0.1517
# Epoch [31/50], Loss: 0.2355
# Accuracy of the model on the test images: 95.13 %
# Validation error of the model on the test images: 0.1505
# Epoch [32/50], Loss: 0.2077
# Accuracy of the model on the test images: 95.35 %
# Validation error of the model on the test images: 0.1445
# Epoch [33/50], Loss: 0.2326
# Accuracy of the model on the test images: 95.35 %
# Validation error of the model on the test images: 0.1442
# Epoch [34/50], Loss: 0.2186
# Accuracy of the model on the test images: 95.40 %
# Validation error of the model on the test images: 0.1427
# Epoch [35/50], Loss: 0.2424
# Accuracy of the model on the test images: 95.47 %
# Validation error of the model on the test images: 0.1406
# Epoch [36/50], Loss: 0.2229
# Accuracy of the model on the test images: 95.50 %
# Validation error of the model on the test images: 0.1395
# Epoch [37/50], Loss: 0.2337
# Accuracy of the model on the test images: 95.72 %
# Validation error of the model on the test images: 0.1381
# Epoch [38/50], Loss: 0.1925
# Epoch [39/50], Loss: 0.1947
# Accuracy of the model on the test images: 95.89 %
# Validation error of the model on the test images: 0.1326
# Epoch [40/50], Loss: 0.2173
# Accuracy of the model on the test images: 95.96 %
# Validation error of the model on the test images: 0.1303
# Epoch [41/50], Loss: 0.2136
# Epoch [42/50], Loss: 0.2498
# Epoch [43/50], Loss: 0.1986
# Epoch [44/50], Loss: 0.2129
# Accuracy of the model on the test images: 96.03 %
# Validation error of the model on the test images: 0.1300
# Epoch [45/50], Loss: 0.2058
# Epoch [46/50], Loss: 0.2275
# Accuracy of the model on the test images: 96.28 %
# Validation error of the model on the test images: 0.1258
# Epoch [47/50], Loss: 0.2251
# Accuracy of the model on the test images: 96.41 %
# Validation error of the model on the test images: 0.1254
# Epoch [48/50], Loss: 0.2235
# Accuracy of the model on the test images: 96.44 %
# Validation error of the model on the test images: 0.1226
# Epoch [49/50], Loss: 0.2255
# Epoch [50/50], Loss: 0.2177

# %%
lamda = 0.9
distill_labels = F.one_hot(teacher_labels_mixed, num_classes=10) * (lamda) + F.one_hot(sets['mixed'].tensors[1], num_classes=10) * (1-lamda)

sets["distill"] = torch.utils.data.TensorDataset(
    sets['mixed'].tensors[0],
    distill_labels,
)

loaders['distill'] = torch.utils.data.DataLoader(sets['distill'], batch_size=batch_size, shuffle=False)

loader=loaders['distill']

train_dist(
    name="student_distil_model", 
    loader=loaders['distill'],
)
student_distil_model = CNN()
student_distil_model.load_state_dict(torch.load("student_distil_model.pth"))
student_distil_model.eval()
None
# Out:
# Epoch [1/50], Loss: 0.2073
# Accuracy of the model on the test images: 74.15 %
# Validation error of the model on the test images: 0.8292
# Epoch [2/50], Loss: 0.1866
# Accuracy of the model on the test images: 78.68 %
# Validation error of the model on the test images: 0.6706
# Epoch [3/50], Loss: 0.1488
# Accuracy of the model on the test images: 82.12 %
# Validation error of the model on the test images: 0.5174
# Epoch [4/50], Loss: 0.1419
# Accuracy of the model on the test images: 83.41 %
# Validation error of the model on the test images: 0.4702
# Epoch [5/50], Loss: 0.1509
# Accuracy of the model on the test images: 85.24 %
# Validation error of the model on the test images: 0.4356
# Epoch [6/50], Loss: 0.1446
# Accuracy of the model on the test images: 86.86 %
# Validation error of the model on the test images: 0.3765
# Epoch [7/50], Loss: 0.0995
# Accuracy of the model on the test images: 87.40 %
# Validation error of the model on the test images: 0.3570
# Epoch [8/50], Loss: 0.0760
# Accuracy of the model on the test images: 87.70 %
# Validation error of the model on the test images: 0.3454
# Epoch [9/50], Loss: 0.1012
# Epoch [10/50], Loss: 0.0888
# Accuracy of the model on the test images: 88.62 %
# Validation error of the model on the test images: 0.3162
# Epoch [11/50], Loss: 0.1055
# Accuracy of the model on the test images: 89.50 %
# Validation error of the model on the test images: 0.2978
# Epoch [12/50], Loss: 0.0868
# Epoch [13/50], Loss: 0.0839
# Accuracy of the model on the test images: 90.97 %
# Validation error of the model on the test images: 0.2518
# Epoch [14/50], Loss: 0.0783
# Epoch [15/50], Loss: 0.0616
# Accuracy of the model on the test images: 91.22 %
# Validation error of the model on the test images: 0.2422
# Epoch [16/50], Loss: 0.0611
# Epoch [17/50], Loss: 0.0758
# Accuracy of the model on the test images: 91.59 %
# Validation error of the model on the test images: 0.2316
# Epoch [18/50], Loss: 0.0700
# Epoch [19/50], Loss: 0.0938
# Accuracy of the model on the test images: 92.28 %
# Validation error of the model on the test images: 0.2146
# Epoch [20/50], Loss: 0.0644
# Accuracy of the model on the test images: 92.78 %
# Validation error of the model on the test images: 0.1986
# Epoch [21/50], Loss: 0.0492
# Epoch [22/50], Loss: 0.0605
# Accuracy of the model on the test images: 93.42 %
# Validation error of the model on the test images: 0.1779
# Epoch [23/50], Loss: 0.0623
# Epoch [24/50], Loss: 0.0464
# Epoch [25/50], Loss: 0.0589
# Accuracy of the model on the test images: 93.72 %
# Validation error of the model on the test images: 0.1727
# Epoch [26/50], Loss: 0.0647
# Accuracy of the model on the test images: 93.63 %
# Validation error of the model on the test images: 0.1726
# Epoch [27/50], Loss: 0.0507
# Accuracy of the model on the test images: 93.65 %
# Validation error of the model on the test images: 0.1713
# Epoch [28/50], Loss: 0.0397
# Accuracy of the model on the test images: 93.80 %
# Validation error of the model on the test images: 0.1698
# Epoch [29/50], Loss: 0.0527
# Accuracy of the model on the test images: 94.36 %
# Validation error of the model on the test images: 0.1550
# Epoch [30/50], Loss: 0.0562
# Accuracy of the model on the test images: 94.44 %
# Validation error of the model on the test images: 0.1516
# Epoch [31/50], Loss: 0.0451
# Accuracy of the model on the test images: 94.72 %
# Validation error of the model on the test images: 0.1442
# Epoch [32/50], Loss: 0.0561
# Accuracy of the model on the test images: 94.56 %
# Validation error of the model on the test images: 0.1438
# Epoch [33/50], Loss: 0.0443
# Epoch [34/50], Loss: 0.0377
# Epoch [35/50], Loss: 0.0525
# Accuracy of the model on the test images: 95.17 %
# Validation error of the model on the test images: 0.1315
# Epoch [36/50], Loss: 0.0481
# Epoch [37/50], Loss: 0.0705
# Epoch [38/50], Loss: 0.0580
# Accuracy of the model on the test images: 95.25 %
# Validation error of the model on the test images: 0.1289
# Epoch [39/50], Loss: 0.0522
# Accuracy of the model on the test images: 95.33 %
# Validation error of the model on the test images: 0.1276
# Epoch [40/50], Loss: 0.0381
# Accuracy of the model on the test images: 95.67 %
# Validation error of the model on the test images: 0.1180
# Epoch [41/50], Loss: 0.0503
# Epoch [42/50], Loss: 0.0362
# Accuracy of the model on the test images: 95.84 %
# Validation error of the model on the test images: 0.1157
# Epoch [43/50], Loss: 0.0345
# Accuracy of the model on the test images: 95.80 %
# Validation error of the model on the test images: 0.1155
# Epoch [44/50], Loss: 0.0634
# Accuracy of the model on the test images: 96.05 %
# Validation error of the model on the test images: 0.1106
# Epoch [45/50], Loss: 0.0403
# Epoch [46/50], Loss: 0.0693
# Epoch [47/50], Loss: 0.0380
# Accuracy of the model on the test images: 96.13 %
# Validation error of the model on the test images: 0.1080
# Epoch [48/50], Loss: 0.0210
# Epoch [49/50], Loss: 0.0341
# Accuracy of the model on the test images: 96.17 %
# Validation error of the model on the test images: 0.1052
# Epoch [50/50], Loss: 0.0566
# Accuracy of the model on the test images: 96.40 %
# Validation error of the model on the test images: 0.0986

# %%
# gchurns_mixed, bchurns_mixed, accuracies_mixed = get_metrics(sets['mixed'].tensors[1], loaders['mixed'])
# metrics_dict_multiple[0.9]["gchurns_mixed"] = gchurns_mixed
# metrics_dict_multiple[0.9]["bchurns_mixed"] = bchurns_mixed
# metrics_dict_multiple[0.9]["accuracies_mixed"] = accuracies_mixed

gchurns_val, bchurns_val, accuracies_val = get_metrics(sets['val'].tensors[1], loaders['val'])
metrics_dict_multiple[0.9]["gchurns_val"] = gchurns_val
metrics_dict_multiple[0.9]["bchurns_val"] = bchurns_val
metrics_dict_multiple[0.9]["accuracies_val"] = accuracies_val
# Out:
# 100%|██████████| 32/32 [00:24<00:00,  1.32it/s]

# %%
metrics_dict_multiple
# Out:
# {0.0: {'gchurns_val': {'baseline': 143, 'add_unlab': 127, 'anchor': 153},
#   'bchurns_val': {'baseline': 270, 'add_unlab': 238, 'anchor': 291},
#   'accuracies_val': {'baseline': 91.5625,
#    'add_unlab': 91.6875,
#    'anchor': 91.375,
#    'teacher': 92.42500305175781}},
#  0.3: {'gchurns_val': {'baseline': 143, 'add_unlab': 144, 'anchor': 134},
#   'bchurns_val': {'baseline': 270, 'add_unlab': 229, 'anchor': 216},
#   'accuracies_val': {'baseline': 91.5625,
#    'add_unlab': 91.98750305175781,
#    'anchor': 91.92500305175781,
#    'teacher': 92.42500305175781}},
#  0.5: {'gchurns_val': {'baseline': 143, 'add_unlab': 107, 'anchor': 131},
#   'bchurns_val': {'baseline': 270, 'add_unlab': 189, 'anchor': 249},
#   'accuracies_val': {'baseline': 91.5625,
#    'add_unlab': 91.9000015258789,
#    'anchor': 91.5250015258789,
#    'teacher': 92.42500305175781}},
#  0.7: {'gchurns_val': {'baseline': 143, 'add_unlab': 115, 'anchor': 124},
#   'bchurns_val': {'baseline': 270, 'add_unlab': 166, 'anchor': 238},
#   'accuracies_val': {'baseline': 91.5625,
#    'add_unlab': 92.1875,
#    'anchor': 91.61250305175781,
#    'teacher': 92.42500305175781}},
#  0.9: {'gchurns_val': {'baseline': 143, 'add_unlab': 114, 'anchor': 107},
#   'bchurns_val': {'baseline': 270, 'add_unlab': 171, 'anchor': 183},
#   'accuracies_val': {'baseline': 91.5625,
#    'add_unlab': 92.05000305175781,
#    'anchor': 91.875,
#    'teacher': 92.42500305175781}}}

# %%
import matplotlib.pyplot as plt

hyperparams = [0.0, 0.3, 0.5, 0.7, 0.9]

# plot accuracies for each model
for model in ['baseline', 'add_unlab', 'anchor']:
    model_accuracies = []
    for hyperparam in hyperparams:
        model_accuracies.append(metrics_dict_multiple[hyperparam]['gchurns_val'][model])
    plt.plot(hyperparams, model_accuracies, label=model)

plt.title('Good Churn for different models')
plt.xlabel('Lambda value')
plt.ylabel('Good Churn')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

hyperparams = [0.0, 0.3, 0.5, 0.7, 0.9]

# plot accuracies for each model
for model in ['baseline', 'add_unlab', 'anchor']:
    model_accuracies = []
    for hyperparam in hyperparams:
        model_accuracies.append(metrics_dict_multiple[hyperparam]['bchurns_val'][model])
    plt.plot(hyperparams, model_accuracies, label=model)

plt.title('Bad Churn for different models')
plt.xlabel('Lambda value')
plt.ylabel('Bad Churn')
plt.legend()
plt.show()

# %%
hyperparams = [0.0, 0.3, 0.5, 0.7, 0.9]

# plot accuracies for each model
for model in ['baseline', 'add_unlab', 'anchor']:
    model_accuracies = []
    for hyperparam in hyperparams:
        model_accuracies.append(metrics_dict_multiple[hyperparam]['accuracies_val'][model])
    plt.plot(hyperparams, model_accuracies, label=model)

plt.title('Bad Churn for different models')
plt.xlabel('Lambda value')
plt.ylabel('Bad Churn')
plt.legend()
plt.show()

# %%
import pandas as pd
# create the pandas dataframe
df = pd.DataFrame.from_dict({(i,j): metrics_dict_multiple[i][j] 
                             for i in metrics_dict_multiple.keys() 
                             for j in metrics_dict_multiple[i].keys()},
                            orient='index')

# save the dataframe as a CSV file
df.to_csv('result_dist_42.csv')
